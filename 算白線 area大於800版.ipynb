# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import cv2

area_prev = 0
area_now = 0
grid_num = 0
i = 1
flag = 0

for i in range(1,2907):      #迴圈次數自己選擇
    img = cv2.imread('%d.jpg' %(i))#路徑自己選擇

# 讀取一張照片
#img = cv2.imread('15.jpg')
    x=375
    y=275
    w=35
    h=30
    img = img[y:y+h, x: x+w]
    

# 不直接指定縮放後大小，通過fx和fy指定縮放比例，0.5則長寬都爲原來一半
# 等效於img_200x300 = cv2.resize(img, (300, 200))，注意指定大小的格式是(寬度,高度)
# 插值方法默認是cv2.INTER_LINEAR，這裏指定爲最近鄰插值
    img = cv2.resize(img, (0, 0), fx=3.5, fy=3.5, 
                              interpolation=cv2.INTER_NEAREST)
    imgContour = img.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    canny = cv2.Canny(img, 70, 210)
    contours, hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)



    peak=0.0
    for cnt in contours:
        area = cv2.contourArea(cnt)
        if area > peak and area > 0:
            peak = area
    print ("Contour #%d — area: %.2f" % (i, peak))
    i=i+1
    """
    #算經過幾格
    flag = 0
    area_now = peak
    if flag == 1 and area_now < area_prev:
        grid_num = grid_num + 1
    if area_now > area_prev:
        flag = 1
    else:
        flag = 0
    area_prev = peak
    """
    if peak > 780:
        if flag == 0:
            grid_num += 1
        flag = 1
    else :
        flag = 0
    print ("grid num = %d"%grid_num )
        
        
    
    for cnt in contours:
    # 每個找出的輪廓
    #cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
    # 藍線框起
        area = cv2.contourArea(cnt)
    #if area > peak:
    #    peak = area
    #print ("Contour #%d — area: %.2f" % (i, area))
    #i=i+1

        if area == peak:
            cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
            #print("Contour drawed area = %.2f" %area)
            #print('%.2f' %cv2.arcLength(cnt, True))
            # True表示輪廓為closed
            peri2 = cv2.arcLength(cnt, False)
            peri = cv2.arcLength(cnt, True)
            #算出周長
            vertices = cv2.approxPolyDP(cnt, peri * 0.2, True)
            vertices2 = cv2.approxPolyDP(cnt, peri2 * 0.2, False)
            #得出多邊形角點
            corners = len(vertices)
            corner = len(vertices2)
            #角點個數
         
            #print(corners)
            #print('123')
            #print(corner)
            x, y, w, h = cv2.boundingRect(vertices)
            
            cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4)
            #a+=1.0
        #while cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4):
             #a+=1
        #if corners == 3:
             #cv2.putText(imgContour,'triangle', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                
                
        #else: 
            cv2.putText(imgContour, 'full', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    #cv2.imshow('img', img)
    #cv2.imshow('canny', canny)
    #cv2.imshow('img%d' %i, imgContour)
    #cv2.waitKey(0) 


# In[ ]:
# Out:
# Contour #1 — area: 861.00
# grid num = 1
# Contour #2 — area: 873.50
# grid num = 1
# Contour #3 — area: 967.50
# grid num = 1
# Contour #4 — area: 1034.00
# grid num = 1
# Contour #5 — area: 1064.00
# grid num = 1
# Contour #6 — area: 1324.00
# grid num = 1
# Contour #7 — area: 1418.50
# grid num = 1
# Contour #8 — area: 523.00
# grid num = 1
# Contour #9 — area: 506.00
# grid num = 1
# Contour #10 — area: 424.50
# grid num = 1
# Contour #11 — area: 374.00
# grid num = 1
# Contour #12 — area: 283.50
# grid num = 1
# Contour #13 — area: 209.00
# grid num = 1
# Contour #14 — area: 220.50
# grid num = 1
# Contour #15 — area: 167.50
# grid num = 1
# Contour #16 — area: 119.00
# grid num = 1
# Contour #17 — area: 137.00
# grid num = 1
# Contour #18 — area: 154.50
# grid num = 1
# Contour #19 — area: 517.00
# grid num = 1
# Contour #20 — area: 507.50
# grid num = 1
# Contour #21 — area: 683.50
# grid num = 1
# Contour #22 — area: 658.00
# grid num = 1
# Contour #23 — area: 707.00
# grid num = 1
# Contour #24 — area: 724.50
# grid num = 1
# Contour #25 — area: 786.00
# grid num = 2
# Contour #26 — area: 874.00
# grid num = 2
# Contour #27 — area: 940.50
# grid num = 2
# Contour #28 — area: 1070.00
# grid num = 2
# Contour #29 — area: 1189.50
# grid num = 2
# Contour #30 — area: 1289.50
# grid num = 2
# Contour #31 — area: 363.50
# grid num = 2
# Contour #32 — area: 342.50
# grid num = 2
# Contour #33 — area: 369.50
# grid num = 2
# Contour #34 — area: 287.50
# grid num = 2
# Contour #35 — area: 379.50
# grid num = 2
# Contour #36 — area: 189.50
# grid num = 2
# Contour #37 — area: 209.00
# grid num = 2
# Contour #38 — area: 91.00
# grid num = 2
# Contour #39 — area: 102.50
# grid num = 2
# Contour #40 — area: 185.50
# grid num = 2
# Contour #41 — area: 181.50
# grid num = 2
# Contour #42 — area: 540.00
# grid num = 2
# Contour #43 — area: 612.50
# grid num = 2
# Contour #44 — area: 689.00
# grid num = 2
# Contour #45 — area: 672.00
# grid num = 2
# Contour #46 — area: 810.00
# grid num = 3
# Contour #47 — area: 847.50
# grid num = 3
# Contour #48 — area: 915.00
# grid num = 3
# Contour #49 — area: 1088.50
# grid num = 3
# Contour #50 — area: 1341.50
# grid num = 3
# Contour #51 — area: 1351.00
# grid num = 3
# Contour #52 — area: 1514.00
# grid num = 3
# Contour #53 — area: 561.00
# grid num = 3
# Contour #54 — area: 666.50
# grid num = 3
# Contour #55 — area: 550.00
# grid num = 3
# Contour #56 — area: 409.50
# grid num = 3
# Contour #57 — area: 483.50
# grid num = 3
# Contour #58 — area: 246.50
# grid num = 3
# Contour #59 — area: 283.50
# grid num = 3
# Contour #60 — area: 178.00
# grid num = 3
# Contour #61 — area: 133.50
# grid num = 3
# Contour #62 — area: 93.00
# grid num = 3
# Contour #63 — area: 120.00
# grid num = 3
# Contour #64 — area: 175.50
# grid num = 3
# Contour #65 — area: 486.50
# grid num = 3
# Contour #66 — area: 685.50
# grid num = 3
# Contour #67 — area: 661.00
# grid num = 3
# Contour #68 — area: 672.00
# grid num = 3
# Contour #69 — area: 820.50
# grid num = 4
# Contour #70 — area: 871.00
# grid num = 4
# Contour #71 — area: 945.00
# grid num = 4
# Contour #72 — area: 1056.00
# grid num = 4
# Contour #73 — area: 1304.50
# grid num = 4
# Contour #74 — area: 1403.00
# grid num = 4
# Contour #75 — area: 440.50
# grid num = 4
# Contour #76 — area: 478.00
# grid num = 4
# Contour #77 — area: 638.50
# grid num = 4
# Contour #78 — area: 514.50
# grid num = 4
# Contour #79 — area: 228.50
# grid num = 4
# Contour #80 — area: 241.50
# grid num = 4
# Contour #81 — area: 200.00
# grid num = 4
# Contour #82 — area: 125.00
# grid num = 4
# Contour #83 — area: 80.00
# grid num = 4
# Contour #84 — area: 145.00
# grid num = 4
# Contour #85 — area: 137.00
# grid num = 4
# Contour #86 — area: 442.00
# grid num = 4
# Contour #87 — area: 500.50
# grid num = 4
# Contour #88 — area: 531.00
# grid num = 4
# Contour #89 — area: 576.50
# grid num = 4
# Contour #90 — area: 694.00
# grid num = 4
# Contour #91 — area: 764.50
# grid num = 4
# Contour #92 — area: 789.00
# grid num = 5
# Contour #93 — area: 924.50
# grid num = 5
# Contour #94 — area: 1165.00
# grid num = 5
# Contour #95 — area: 1071.00
# grid num = 5
# Contour #96 — area: 1168.50
# grid num = 5
# Contour #97 — area: 1366.50
# grid num = 5
# Contour #98 — area: 511.00
# grid num = 5
# Contour #99 — area: 572.50
# grid num = 5
# Contour #100 — area: 518.50
# grid num = 5
# Contour #101 — area: 512.00
# grid num = 5
# Contour #102 — area: 236.50
# grid num = 5
# Contour #103 — area: 296.00
# grid num = 5
# Contour #104 — area: 313.00
# grid num = 5
# Contour #105 — area: 185.50
# grid num = 5
# Contour #106 — area: 174.50
# grid num = 5
# Contour #107 — area: 168.50
# grid num = 5
# Contour #108 — area: 115.50
# grid num = 5
# Contour #109 — area: 181.50
# grid num = 5
# Contour #110 — area: 186.50
# grid num = 5
# Contour #111 — area: 438.00
# grid num = 5
# Contour #112 — area: 527.00
# grid num = 5
# Contour #113 — area: 640.50
# grid num = 5
# Contour #114 — area: 746.00
# grid num = 5
# Contour #115 — area: 812.00
# grid num = 6
# Contour #116 — area: 842.00
# grid num = 6
# Contour #117 — area: 914.50
# grid num = 6
# Contour #118 — area: 1016.00
# grid num = 6
# Contour #119 — area: 1250.00
# grid num = 6
# Contour #120 — area: 1257.50
# grid num = 6
# Contour #121 — area: 615.00
# grid num = 6
# Contour #122 — area: 565.50
# grid num = 6
# Contour #123 — area: 553.00
# grid num = 6
# Contour #124 — area: 357.00
# grid num = 6
# Contour #125 — area: 341.00
# grid num = 6
# Contour #126 — area: 395.50
# grid num = 6
# Contour #127 — area: 307.50
# grid num = 6
# Contour #128 — area: 240.50
# grid num = 6
# Contour #129 — area: 192.50
# grid num = 6
# Contour #130 — area: 105.50
# grid num = 6
# Contour #131 — area: 227.00
# grid num = 6
# Contour #132 — area: 161.50
# grid num = 6
# Contour #133 — area: 179.00
# grid num = 6
# Contour #134 — area: 552.50
# grid num = 6
# Contour #135 — area: 584.50
# grid num = 6
# Contour #136 — area: 708.50
# grid num = 6
# Contour #137 — area: 747.50
# grid num = 6
# Contour #138 — area: 782.50
# grid num = 7
# Contour #139 — area: 853.00
# grid num = 7
# Contour #140 — area: 1035.00
# grid num = 7
# Contour #141 — area: 1071.50
# grid num = 7
# Contour #142 — area: 1166.00
# grid num = 7
# Contour #143 — area: 1339.00
# grid num = 7
# Contour #144 — area: 396.50
# grid num = 7
# Contour #145 — area: 567.50
# grid num = 7
# Contour #146 — area: 444.00
# grid num = 7
# Contour #147 — area: 451.50
# grid num = 7
# Contour #148 — area: 389.50
# grid num = 7
# Contour #149 — area: 236.00
# grid num = 7
# Contour #150 — area: 181.00
# grid num = 7
# Contour #151 — area: 95.00
# grid num = 7
# Contour #152 — area: 120.00
# grid num = 7
# Contour #153 — area: 128.50
# grid num = 7
# Contour #154 — area: 186.00
# grid num = 7
# Contour #155 — area: 259.00
# grid num = 7
# Contour #156 — area: 169.00
# grid num = 7
# Contour #157 — area: 419.00
# grid num = 7
# Contour #158 — area: 592.00
# grid num = 7
# Contour #159 — area: 601.00
# grid num = 7
# Contour #160 — area: 749.50
# grid num = 7
# Contour #161 — area: 725.00
# grid num = 7
# Contour #162 — area: 779.50
# grid num = 7
# Contour #163 — area: 812.50
# grid num = 8
# Contour #164 — area: 957.50
# grid num = 8
# Contour #165 — area: 991.00
# grid num = 8
# Contour #166 — area: 1082.50
# grid num = 8
# Contour #167 — area: 332.50
# grid num = 8
# Contour #168 — area: 353.50
# grid num = 8
# Contour #169 — area: 290.50
# grid num = 8
# Contour #170 — area: 231.50
# grid num = 8
# Contour #171 — area: 203.00
# grid num = 8
# Contour #172 — area: 193.00
# grid num = 8
# Contour #173 — area: 171.50
# grid num = 8
# Contour #174 — area: 205.50
# grid num = 8
# Contour #175 — area: 123.00
# grid num = 8
# Contour #176 — area: 154.50
# grid num = 8
# Contour #177 — area: 165.50
# grid num = 8
# Contour #178 — area: 187.50
# grid num = 8
# Contour #179 — area: 149.50
# grid num = 8
# Contour #180 — area: 270.50
# grid num = 8
# Contour #181 — area: 219.00
# grid num = 8
# Contour #182 — area: 763.50
# grid num = 8
# Contour #183 — area: 834.50
# grid num = 9
# Contour #184 — area: 878.50
# grid num = 9
# Contour #185 — area: 938.00
# grid num = 9
# Contour #186 — area: 1204.50
# grid num = 9
# Contour #187 — area: 546.00
# grid num = 9
# Contour #188 — area: 534.50
# grid num = 9
# Contour #189 — area: 287.50
# grid num = 9
# Contour #190 — area: 257.50
# grid num = 9
# Contour #191 — area: 225.00
# grid num = 9
# Contour #192 — area: 434.50
# grid num = 9
# Contour #193 — area: 392.50
# grid num = 9
# Contour #194 — area: 264.50
# grid num = 9
# Contour #195 — area: 275.50
# grid num = 9
# Contour #196 — area: 204.00
# grid num = 9
# Contour #197 — area: 186.50
# grid num = 9
# Contour #198 — area: 140.00
# grid num = 9
# Contour #199 — area: 59.00
# grid num = 9
# Contour #200 — area: 91.50
# grid num = 9
# Contour #201 — area: 76.50
# grid num = 9
# Contour #202 — area: 101.50
# grid num = 9
# Contour #203 — area: 176.50
# grid num = 9
# Contour #204 — area: 233.00
# grid num = 9
# Contour #205 — area: 280.00
# grid num = 9
# Contour #206 — area: 784.50
# grid num = 10
# Contour #207 — area: 822.00
# grid num = 10
# Contour #208 — area: 923.50
# grid num = 10
# Contour #209 — area: 925.00
# grid num = 10
# Contour #210 — area: 1149.00
# grid num = 10
# Contour #211 — area: 1189.50
# grid num = 10
# Contour #212 — area: 475.50
# grid num = 10
# Contour #213 — area: 392.50
# grid num = 10
# Contour #214 — area: 326.00
# grid num = 10
# Contour #215 — area: 270.50
# grid num = 10
# Contour #216 — area: 282.50
# grid num = 10
# Contour #217 — area: 268.00
# grid num = 10
# Contour #218 — area: 231.00
# grid num = 10
# Contour #219 — area: 111.00
# grid num = 10
# Contour #220 — area: 88.00
# grid num = 10
# Contour #221 — area: 95.50
# grid num = 10
# Contour #222 — area: 135.50
# grid num = 10
# Contour #223 — area: 63.50
# grid num = 10
# Contour #224 — area: 197.00
# grid num = 10
# Contour #225 — area: 527.50
# grid num = 10
# Contour #226 — area: 602.00
# grid num = 10
# Contour #227 — area: 644.00
# grid num = 10
# Contour #228 — area: 793.00
# grid num = 11
# Contour #229 — area: 812.00
# grid num = 11
# Contour #230 — area: 910.00
# grid num = 11
# Contour #231 — area: 965.00
# grid num = 11
# Contour #232 — area: 1049.50
# grid num = 11
# Contour #233 — area: 1163.00
# grid num = 11
# Contour #234 — area: 1243.50
# grid num = 11
# Contour #235 — area: 303.50
# grid num = 11
# Contour #236 — area: 303.50
# grid num = 11
# Contour #237 — area: 195.00
# grid num = 11
# Contour #238 — area: 271.00
# grid num = 11
# Contour #239 — area: 232.00
# grid num = 11
# Contour #240 — area: 228.50
# grid num = 11
# Contour #241 — area: 122.00
# grid num = 11
# Contour #242 — area: 90.00
# grid num = 11
# Contour #243 — area: 65.50
# grid num = 11
# Contour #244 — area: 102.00
# grid num = 11
# Contour #245 — area: 203.50
# grid num = 11
# Contour #246 — area: 146.00
# grid num = 11
# Contour #247 — area: 173.50
# grid num = 11
# Contour #248 — area: 271.00
# grid num = 11
# Contour #249 — area: 684.50
# grid num = 11
# Contour #250 — area: 753.00
# grid num = 11
# Contour #251 — area: 806.50
# grid num = 12
# Contour #252 — area: 901.00
# grid num = 12
# Contour #253 — area: 891.00
# grid num = 12
# Contour #254 — area: 1025.00
# grid num = 12
# Contour #255 — area: 1188.50
# grid num = 12
# Contour #256 — area: 1394.50
# grid num = 12
# Contour #257 — area: 517.50
# grid num = 12
# Contour #258 — area: 434.00
# grid num = 12
# Contour #259 — area: 374.00
# grid num = 12
# Contour #260 — area: 346.00
# grid num = 12
# Contour #261 — area: 352.00
# grid num = 12
# Contour #262 — area: 278.00
# grid num = 12
# Contour #263 — area: 201.00
# grid num = 12
# Contour #264 — area: 132.50
# grid num = 12
# Contour #265 — area: 118.00
# grid num = 12
# Contour #266 — area: 76.50
# grid num = 12
# Contour #267 — area: 107.50
# grid num = 12
# Contour #268 — area: 139.50
# grid num = 12
# Contour #269 — area: 185.00
# grid num = 12
# Contour #270 — area: 217.00
# grid num = 12
# Contour #271 — area: 646.50
# grid num = 12
# Contour #272 — area: 776.50
# grid num = 12
# Contour #273 — area: 912.00
# grid num = 13
# Contour #274 — area: 904.00
# grid num = 13
# Contour #275 — area: 945.00
# grid num = 13
# Contour #276 — area: 1078.00
# grid num = 13
# Contour #277 — area: 1317.00
# grid num = 13
# Contour #278 — area: 1306.50
# grid num = 13
# Contour #279 — area: 1416.00
# grid num = 13
# Contour #280 — area: 1580.50
# grid num = 13
# Contour #281 — area: 634.00
# grid num = 13
# Contour #282 — area: 474.50
# grid num = 13
# Contour #283 — area: 536.00
# grid num = 13
# Contour #284 — area: 363.50
# grid num = 13
# Contour #285 — area: 311.50
# grid num = 13
# Contour #286 — area: 263.00
# grid num = 13
# Contour #287 — area: 227.00
# grid num = 13
# Contour #288 — area: 134.00
# grid num = 13
# Contour #289 — area: 83.00
# grid num = 13
# Contour #290 — area: 117.00
# grid num = 13
# Contour #291 — area: 87.50
# grid num = 13
# Contour #292 — area: 127.50
# grid num = 13
# Contour #293 — area: 241.50
# grid num = 13
# Contour #294 — area: 247.00
# grid num = 13
# Contour #295 — area: 220.50
# grid num = 13
# Contour #296 — area: 804.00
# grid num = 14
# Contour #297 — area: 800.00
# grid num = 14
# Contour #298 — area: 907.50
# grid num = 14
# Contour #299 — area: 986.50
# grid num = 14
# Contour #300 — area: 1112.50
# grid num = 14
# Contour #301 — area: 1213.00
# grid num = 14
# Contour #302 — area: 1364.50
# grid num = 14
# Contour #303 — area: 502.50
# grid num = 14
# Contour #304 — area: 443.50
# grid num = 14
# Contour #305 — area: 457.50
# grid num = 14
# Contour #306 — area: 475.00
# grid num = 14
# Contour #307 — area: 308.00
# grid num = 14
# Contour #308 — area: 358.50
# grid num = 14
# Contour #309 — area: 379.50
# grid num = 14
# Contour #310 — area: 226.00
# grid num = 14
# Contour #311 — area: 152.50
# grid num = 14
# Contour #312 — area: 73.00
# grid num = 14
# Contour #313 — area: 59.50
# grid num = 14
# Contour #314 — area: 169.00
# grid num = 14
# Contour #315 — area: 159.00
# grid num = 14
# Contour #316 — area: 182.00
# grid num = 14
# Contour #317 — area: 172.50
# grid num = 14
# Contour #318 — area: 676.00
# grid num = 14
# Contour #319 — area: 772.50
# grid num = 14
# Contour #320 — area: 993.50
# grid num = 15
# Contour #321 — area: 1137.00
# grid num = 15
# Contour #322 — area: 1052.00
# grid num = 15
# Contour #323 — area: 1284.50
# grid num = 15
# Contour #324 — area: 1469.50
# grid num = 15
# Contour #325 — area: 1715.00
# grid num = 15
# Contour #326 — area: 574.50
# grid num = 15
# Contour #327 — area: 676.00
# grid num = 15
# Contour #328 — area: 451.50
# grid num = 15
# Contour #329 — area: 375.00
# grid num = 15
# Contour #330 — area: 299.50
# grid num = 15
# Contour #331 — area: 299.00
# grid num = 15
# Contour #332 — area: 137.00
# grid num = 15
# Contour #333 — area: 100.50
# grid num = 15
# Contour #334 — area: 68.50
# grid num = 15
# Contour #335 — area: 108.50
# grid num = 15
# Contour #336 — area: 141.00
# grid num = 15
# Contour #337 — area: 173.50
# grid num = 15
# Contour #338 — area: 552.50
# grid num = 15
# Contour #339 — area: 576.50
# grid num = 15
# Contour #340 — area: 632.00
# grid num = 15
# Contour #341 — area: 759.00
# grid num = 15
# Contour #342 — area: 765.50
# grid num = 15
# Contour #343 — area: 351.50
# grid num = 15
# Contour #344 — area: 959.00
# grid num = 16
# Contour #345 — area: 1189.00
# grid num = 16
# Contour #346 — area: 1096.00
# grid num = 16
# Contour #347 — area: 1334.00
# grid num = 16
# Contour #348 — area: 478.00
# grid num = 16
# Contour #349 — area: 335.00
# grid num = 16
# Contour #350 — area: 345.50
# grid num = 16
# Contour #351 — area: 292.50
# grid num = 16
# Contour #352 — area: 207.50
# grid num = 16
# Contour #353 — area: 268.50
# grid num = 16
# Contour #354 — area: 82.50
# grid num = 16
# Contour #355 — area: 92.00
# grid num = 16
# Contour #356 — area: 63.50
# grid num = 16
# Contour #357 — area: 86.50
# grid num = 16
# Contour #358 — area: 101.50
# grid num = 16
# Contour #359 — area: 74.00
# grid num = 16
# Contour #360 — area: 169.50
# grid num = 16
# Contour #361 — area: 586.00
# grid num = 16
# Contour #362 — area: 628.00
# grid num = 16
# Contour #363 — area: 702.00
# grid num = 16
# Contour #364 — area: 779.00
# grid num = 16
# Contour #365 — area: 804.00
# grid num = 17
# Contour #366 — area: 859.00
# grid num = 17
# Contour #367 — area: 956.50
# grid num = 17
# Contour #368 — area: 1082.00
# grid num = 17
# Contour #369 — area: 296.00
# grid num = 17
# Contour #370 — area: 276.00
# grid num = 17
# Contour #371 — area: 294.50
# grid num = 17
# Contour #372 — area: 267.00
# grid num = 17
# Contour #373 — area: 199.50
# grid num = 17
# Contour #374 — area: 176.00
# grid num = 17
# Contour #375 — area: 131.50
# grid num = 17
# Contour #376 — area: 153.00
# grid num = 17
# Contour #377 — area: 74.00
# grid num = 17
# Contour #378 — area: 49.50
# grid num = 17
# Contour #379 — area: 23.00
# grid num = 17
# Contour #380 — area: 38.50
# grid num = 17
# Contour #381 — area: 14.00
# grid num = 17
# Contour #382 — area: 54.50
# grid num = 17
# Contour #383 — area: 54.00
# grid num = 17
# Contour #384 — area: 41.50
# grid num = 17
# Contour #385 — area: 61.00
# grid num = 17
# Contour #386 — area: 125.00
# grid num = 17
# Contour #387 — area: 681.50
# grid num = 17
# Contour #388 — area: 811.00
# grid num = 18
# Contour #389 — area: 842.50
# grid num = 18
# Contour #390 — area: 1001.50
# grid num = 18
# Contour #391 — area: 984.50
# grid num = 18
# Contour #392 — area: 240.00
# grid num = 18
# Contour #393 — area: 243.50
# grid num = 18
# Contour #394 — area: 180.00
# grid num = 18
# Contour #395 — area: 149.50
# grid num = 18
# Contour #396 — area: 131.50
# grid num = 18
# Contour #397 — area: 156.00
# grid num = 18
# Contour #398 — area: 178.00
# grid num = 18
# Contour #399 — area: 45.00
# grid num = 18
# Contour #400 — area: 31.50
# grid num = 18
# Contour #401 — area: 33.00
# grid num = 18
# Contour #402 — area: 43.50
# grid num = 18
# Contour #403 — area: 66.50
# grid num = 18
# Contour #404 — area: 78.00
# grid num = 18
# Contour #405 — area: 107.00
# grid num = 18
# Contour #406 — area: 113.50
# grid num = 18
# Contour #407 — area: 100.50
# grid num = 18
# Contour #408 — area: 148.00
# grid num = 18
# Contour #409 — area: 680.50
# grid num = 18
# Contour #410 — area: 739.00
# grid num = 18
# Contour #411 — area: 775.00
# grid num = 18
# Contour #412 — area: 894.00
# grid num = 19
# Contour #413 — area: 907.00
# grid num = 19
# Contour #414 — area: 1024.00
# grid num = 19
# Contour #415 — area: 326.00
# grid num = 19
# Contour #416 — area: 357.00
# grid num = 19
# Contour #417 — area: 237.00
# grid num = 19
# Contour #418 — area: 239.00
# grid num = 19
# Contour #419 — area: 200.50
# grid num = 19
# Contour #420 — area: 153.00
# grid num = 19
# Contour #421 — area: 150.00
# grid num = 19
# Contour #422 — area: 144.50
# grid num = 19
# Contour #423 — area: 94.50
# grid num = 19
# Contour #424 — area: 64.00
# grid num = 19
# Contour #425 — area: 88.00
# grid num = 19
# Contour #426 — area: 42.50
# grid num = 19
# Contour #427 — area: 124.00
# grid num = 19
# Contour #428 — area: 95.00
# grid num = 19
# Contour #429 — area: 83.00
# grid num = 19
# Contour #430 — area: 107.50
# grid num = 19
# Contour #431 — area: 85.00
# grid num = 19
# Contour #432 — area: 201.00
# grid num = 19
# Contour #433 — area: 121.50
# grid num = 19
# Contour #434 — area: 959.50
# grid num = 20
# Contour #435 — area: 933.50
# grid num = 20
# Contour #436 — area: 251.00
# grid num = 20
# Contour #437 — area: 294.00
# grid num = 20
# Contour #438 — area: 373.50
# grid num = 20
# Contour #439 — area: 356.50
# grid num = 20
# Contour #440 — area: 288.50
# grid num = 20
# Contour #441 — area: 215.50
# grid num = 20
# Contour #442 — area: 153.00
# grid num = 20
# Contour #443 — area: 140.00
# grid num = 20
# Contour #444 — area: 169.50
# grid num = 20
# Contour #445 — area: 72.00
# grid num = 20
# Contour #446 — area: 47.00
# grid num = 20
# Contour #447 — area: 55.50
# grid num = 20
# Contour #448 — area: 34.00
# grid num = 20
# Contour #449 — area: 15.50
# grid num = 20
# Contour #450 — area: 47.50
# grid num = 20
# Contour #451 — area: 103.50
# grid num = 20
# Contour #452 — area: 71.50
# grid num = 20
# Contour #453 — area: 211.50
# grid num = 20
# Contour #454 — area: 115.00
# grid num = 20
# Contour #455 — area: 730.00
# grid num = 20
# Contour #456 — area: 792.00
# grid num = 21
# Contour #457 — area: 125.00
# grid num = 21
# Contour #458 — area: 1019.00
# grid num = 22
# Contour #459 — area: 1091.00
# grid num = 22
# Contour #460 — area: 1185.00
# grid num = 22
# Contour #461 — area: 262.50
# grid num = 22
# Contour #462 — area: 274.50
# grid num = 22
# Contour #463 — area: 178.50
# grid num = 22
# Contour #464 — area: 170.50
# grid num = 22
# Contour #465 — area: 170.50
# grid num = 22
# Contour #466 — area: 113.50
# grid num = 22
# Contour #467 — area: 94.00
# grid num = 22
# Contour #468 — area: 35.50
# grid num = 22
# Contour #469 — area: 26.50
# grid num = 22
# Contour #470 — area: 354.50
# grid num = 22
# Contour #471 — area: 408.00
# grid num = 22
# Contour #472 — area: 121.00
# grid num = 22
# Contour #473 — area: 51.50
# grid num = 22
# Contour #474 — area: 90.00
# grid num = 22
# Contour #475 — area: 113.00
# grid num = 22
# Contour #476 — area: 604.00
# grid num = 22
# Contour #477 — area: 574.00
# grid num = 22
# Contour #478 — area: 714.00
# grid num = 22
# Contour #479 — area: 684.00
# grid num = 22
# Contour #480 — area: 799.00
# grid num = 23
# Contour #481 — area: 301.00
# grid num = 23
# Contour #482 — area: 240.00
# grid num = 23
# Contour #483 — area: 236.50
# grid num = 23
# Contour #484 — area: 237.50
# grid num = 23
# Contour #485 — area: 270.00
# grid num = 23
# Contour #486 — area: 236.50
# grid num = 23
# Contour #487 — area: 160.50
# grid num = 23
# Contour #488 — area: 192.50
# grid num = 23
# Contour #489 — area: 129.00
# grid num = 23
# Contour #490 — area: 126.50
# grid num = 23
# Contour #491 — area: 72.00
# grid num = 23
# Contour #492 — area: 61.50
# grid num = 23
# Contour #493 — area: 75.50
# grid num = 23
# Contour #494 — area: 76.00
# grid num = 23
# Contour #495 — area: 109.50
# grid num = 23
# Contour #496 — area: 112.50
# grid num = 23
# Contour #497 — area: 592.00
# grid num = 23
# Contour #498 — area: 559.00
# grid num = 23
# Contour #499 — area: 618.00
# grid num = 23
# Contour #500 — area: 659.50
# grid num = 23
# Contour #501 — area: 752.50
# grid num = 23
# Contour #502 — area: 869.50
# grid num = 24
# Contour #503 — area: 825.00
# grid num = 24
# Contour #504 — area: 1045.50
# grid num = 24
# Contour #505 — area: 1064.00
# grid num = 24
# Contour #506 — area: 1226.50
# grid num = 24
# Contour #507 — area: 277.50
# grid num = 24
# Contour #508 — area: 233.00
# grid num = 24
# Contour #509 — area: 84.50
# grid num = 24
# Contour #510 — area: 194.00
# grid num = 24
# Contour #511 — area: 121.00
# grid num = 24
# Contour #512 — area: 79.50
# grid num = 24
# Contour #513 — area: 77.00
# grid num = 24
# Contour #514 — area: 48.00
# grid num = 24
# Contour #515 — area: 18.00
# grid num = 24
# Contour #516 — area: 29.00
# grid num = 24
# Contour #517 — area: 74.50
# grid num = 24
# Contour #518 — area: 65.00
# grid num = 24
# Contour #519 — area: 154.00
# grid num = 24
# Contour #520 — area: 107.00
# grid num = 24
# Contour #521 — area: 165.00
# grid num = 24
# Contour #522 — area: 229.00
# grid num = 24
# Contour #523 — area: 296.00
# grid num = 24
# Contour #524 — area: 240.00
# grid num = 24
# Contour #525 — area: 182.50
# grid num = 24
# Contour #526 — area: 400.50
# grid num = 24
# Contour #527 — area: 1104.50
# grid num = 25
# Contour #528 — area: 1172.50
# grid num = 25
# Contour #529 — area: 1212.50
# grid num = 25
# Contour #530 — area: 1371.50
# grid num = 25
# Contour #531 — area: 1429.00
# grid num = 25
# Contour #532 — area: 415.00
# grid num = 25
# Contour #533 — area: 559.50
# grid num = 25
# Contour #534 — area: 662.00
# grid num = 25
# Contour #535 — area: 352.50
# grid num = 25
# Contour #536 — area: 419.50
# grid num = 25
# Contour #537 — area: 245.50
# grid num = 25
# Contour #538 — area: 301.00
# grid num = 25
# Contour #539 — area: 289.00
# grid num = 25
# Contour #540 — area: 210.00
# grid num = 25
# Contour #541 — area: 72.50
# grid num = 25
# Contour #542 — area: 131.00
# grid num = 25
# Contour #543 — area: 178.50
# grid num = 25
# Contour #544 — area: 158.50
# grid num = 25
# Contour #545 — area: 671.00
# grid num = 25
# Contour #546 — area: 754.50
# grid num = 25
# Contour #547 — area: 806.00
# grid num = 26
# Contour #548 — area: 903.50
# grid num = 26
# Contour #549 — area: 965.50
# grid num = 26
# Contour #550 — area: 1081.50
# grid num = 26
# Contour #551 — area: 1324.50
# grid num = 26
# Contour #552 — area: 355.00
# grid num = 26
# Contour #553 — area: 369.50
# grid num = 26
# Contour #554 — area: 290.00
# grid num = 26
# Contour #555 — area: 328.00
# grid num = 26
# Contour #556 — area: 316.50
# grid num = 26
# Contour #557 — area: 268.00
# grid num = 26
# Contour #558 — area: 244.50
# grid num = 26
# Contour #559 — area: 219.50
# grid num = 26
# Contour #560 — area: 116.50
# grid num = 26
# Contour #561 — area: 60.50
# grid num = 26
# Contour #562 — area: 35.50
# grid num = 26
# Contour #563 — area: 112.00
# grid num = 26
# Contour #564 — area: 106.50
# grid num = 26
# Contour #565 — area: 185.50
# grid num = 26
# Contour #566 — area: 220.50
# grid num = 26
# Contour #567 — area: 613.50
# grid num = 26
# Contour #568 — area: 628.00
# grid num = 26
# Contour #569 — area: 743.50
# grid num = 26
# Contour #570 — area: 867.50
# grid num = 27
# Contour #571 — area: 949.00
# grid num = 27
# Contour #572 — area: 995.50
# grid num = 27
# Contour #573 — area: 1060.50
# grid num = 27
# Contour #574 — area: 404.00
# grid num = 27
# Contour #575 — area: 371.50
# grid num = 27
# Contour #576 — area: 319.00
# grid num = 27
# Contour #577 — area: 312.50
# grid num = 27
# Contour #578 — area: 290.00
# grid num = 27
# Contour #579 — area: 260.00
# grid num = 27
# Contour #580 — area: 240.00
# grid num = 27
# Contour #581 — area: 150.50
# grid num = 27
# Contour #582 — area: 124.00
# grid num = 27
# Contour #583 — area: 85.50
# grid num = 27
# Contour #584 — area: 59.50
# grid num = 27
# Contour #585 — area: 123.00
# grid num = 27
# Contour #586 — area: 103.50
# grid num = 27
# Contour #587 — area: 124.00
# grid num = 27
# Contour #588 — area: 112.50
# grid num = 27
# Contour #589 — area: 132.00
# grid num = 27
# Contour #590 — area: 151.50
# grid num = 27
# Contour #591 — area: 672.00
# grid num = 27
# Contour #592 — area: 174.50
# grid num = 27
# Contour #593 — area: 910.50
# grid num = 28
# Contour #594 — area: 934.50
# grid num = 28
# Contour #595 — area: 1102.00
# grid num = 28
# Contour #596 — area: 252.50
# grid num = 28
# Contour #597 — area: 240.50
# grid num = 28
# Contour #598 — area: 194.00
# grid num = 28
# Contour #599 — area: 176.00
# grid num = 28
# Contour #600 — area: 105.50
# grid num = 28
# Contour #601 — area: 158.50
# grid num = 28
# Contour #602 — area: 110.00
# grid num = 28
# Contour #603 — area: 77.50
# grid num = 28
# Contour #604 — area: 57.50
# grid num = 28
# Contour #605 — area: 47.50
# grid num = 28
# Contour #606 — area: 22.00
# grid num = 28
# Contour #607 — area: 1.00
# grid num = 28
# Contour #608 — area: 0.00
# grid num = 28
# Contour #609 — area: 0.00
# grid num = 28
# Contour #610 — area: 0.00
# grid num = 28
# Contour #611 — area: 0.00
# grid num = 28
# Contour #612 — area: 0.00
# grid num = 28
# Contour #613 — area: 0.00
# grid num = 28
# Contour #614 — area: 0.00
# grid num = 28
# Contour #615 — area: 0.00
# grid num = 28
# Contour #616 — area: 0.00
# grid num = 28
# Contour #617 — area: 0.00
# grid num = 28
# Contour #618 — area: 0.00
# grid num = 28
# Contour #619 — area: 0.00
# grid num = 28
# Contour #620 — area: 0.00
# grid num = 28
# Contour #621 — area: 0.00
# grid num = 28
# Contour #622 — area: 0.00
# grid num = 28
# Contour #623 — area: 0.00
# grid num = 28
# Contour #624 — area: 0.00
# grid num = 28
# Contour #625 — area: 0.00
# grid num = 28
# Contour #626 — area: 0.00
# grid num = 28
# Contour #627 — area: 0.00
# grid num = 28
# Contour #628 — area: 0.00
# grid num = 28
# Contour #629 — area: 0.00
# grid num = 28
# Contour #630 — area: 0.00
# grid num = 28
# Contour #631 — area: 0.00
# grid num = 28
# Contour #632 — area: 0.00
# grid num = 28
# Contour #633 — area: 0.00
# grid num = 28
# Contour #634 — area: 0.00
# grid num = 28
# Contour #635 — area: 0.00
# grid num = 28
# Contour #636 — area: 0.00
# grid num = 28
# Contour #637 — area: 0.00
# grid num = 28
# Contour #638 — area: 0.00
# grid num = 28
# Contour #639 — area: 0.00
# grid num = 28
# Contour #640 — area: 0.00
# grid num = 28
# Contour #641 — area: 0.00
# grid num = 28
# Contour #642 — area: 0.00
# grid num = 28
# Contour #643 — area: 0.00
# grid num = 28
# Contour #644 — area: 0.00
# grid num = 28
# Contour #645 — area: 0.00
# grid num = 28
# Contour #646 — area: 0.00
# grid num = 28
# Contour #647 — area: 0.00
# grid num = 28
# Contour #648 — area: 0.00
# grid num = 28
# Contour #649 — area: 0.00
# grid num = 28
# Contour #650 — area: 0.00
# grid num = 28
# Contour #651 — area: 0.00
# grid num = 28
# Contour #652 — area: 0.00
# grid num = 28
# Contour #653 — area: 0.00
# grid num = 28
# Contour #654 — area: 0.00
# grid num = 28
# Contour #655 — area: 0.00
# grid num = 28
# Contour #656 — area: 0.00
# grid num = 28
# Contour #657 — area: 0.00
# grid num = 28
# Contour #658 — area: 0.00
# grid num = 28
# Contour #659 — area: 0.00
# grid num = 28
# Contour #660 — area: 0.00
# grid num = 28
# Contour #661 — area: 0.00
# grid num = 28
# Contour #662 — area: 0.00
# grid num = 28
# Contour #663 — area: 0.00
# grid num = 28
# Contour #664 — area: 0.00
# grid num = 28
# Contour #665 — area: 0.00
# grid num = 28
# Contour #666 — area: 0.00
# grid num = 28
# Contour #667 — area: 0.00
# grid num = 28
# Contour #668 — area: 0.00
# grid num = 28
# Contour #669 — area: 12.50
# grid num = 28
# Contour #670 — area: 4.00
# grid num = 28
# Contour #671 — area: 8.50
# grid num = 28
# Contour #672 — area: 5.00
# grid num = 28
# Contour #673 — area: 15.50
# grid num = 28
# Contour #674 — area: 3.00
# grid num = 28
# Contour #675 — area: 0.00
# grid num = 28
# Contour #676 — area: 0.00
# grid num = 28
# Contour #677 — area: 0.00
# grid num = 28
# Contour #678 — area: 0.00
# grid num = 28
# Contour #679 — area: 0.00
# grid num = 28
# Contour #680 — area: 0.00
# grid num = 28
# Contour #681 — area: 0.00
# grid num = 28
# Contour #682 — area: 0.00
# grid num = 28
# Contour #683 — area: 0.00
# grid num = 28
# Contour #684 — area: 0.00
# grid num = 28
# Contour #685 — area: 0.00
# grid num = 28
# Contour #686 — area: 0.00
# grid num = 28
# Contour #687 — area: 0.00
# grid num = 28
# Contour #688 — area: 0.00
# grid num = 28
# Contour #689 — area: 6.50
# grid num = 28
# Contour #690 — area: 0.00
# grid num = 28
# Contour #691 — area: 2.00
# grid num = 28
# Contour #692 — area: 29.00
# grid num = 28
# Contour #693 — area: 33.00
# grid num = 28
# Contour #694 — area: 16.00
# grid num = 28
# Contour #695 — area: 15.00
# grid num = 28
# Contour #696 — area: 7.50
# grid num = 28
# Contour #697 — area: 0.00
# grid num = 28
# Contour #698 — area: 11.00
# grid num = 28
# Contour #699 — area: 7.50
# grid num = 28
# Contour #700 — area: 16.00
# grid num = 28
# Contour #701 — area: 23.00
# grid num = 28
# Contour #702 — area: 52.00
# grid num = 28
# Contour #703 — area: 18.50
# grid num = 28
# Contour #704 — area: 36.50
# grid num = 28
# Contour #705 — area: 30.00
# grid num = 28
# Contour #706 — area: 37.00
# grid num = 28
# Contour #707 — area: 64.00
# grid num = 28
# Contour #708 — area: 44.00
# grid num = 28
# Contour #709 — area: 41.00
# grid num = 28
# Contour #710 — area: 69.00
# grid num = 28
# Contour #711 — area: 55.50
# grid num = 28
# Contour #712 — area: 40.00
# grid num = 28
# Contour #713 — area: 12.00
# grid num = 28
# Contour #714 — area: 10.00
# grid num = 28
# Contour #715 — area: 25.00
# grid num = 28
# Contour #716 — area: 12.00
# grid num = 28
# Contour #717 — area: 0.00
# grid num = 28
# Contour #718 — area: 0.00
# grid num = 28
# Contour #719 — area: 0.00
# grid num = 28
# Contour #720 — area: 0.00
# grid num = 28
# Contour #721 — area: 0.00
# grid num = 28
# Contour #722 — area: 0.00
# grid num = 28
# Contour #723 — area: 0.00
# grid num = 28
# Contour #724 — area: 0.00
# grid num = 28
# Contour #725 — area: 2.00
# grid num = 28
# Contour #726 — area: 0.00
# grid num = 28
# Contour #727 — area: 0.00
# grid num = 28
# Contour #728 — area: 7.00
# grid num = 28
# Contour #729 — area: 0.00
# grid num = 28
# Contour #730 — area: 4.50
# grid num = 28
# Contour #731 — area: 0.00
# grid num = 28
# Contour #732 — area: 24.50
# grid num = 28
# Contour #733 — area: 36.00
# grid num = 28
# Contour #734 — area: 38.00
# grid num = 28
# Contour #735 — area: 28.00
# grid num = 28
# Contour #736 — area: 27.00
# grid num = 28
# Contour #737 — area: 29.00
# grid num = 28
# Contour #738 — area: 28.50
# grid num = 28
# Contour #739 — area: 15.50
# grid num = 28
# Contour #740 — area: 3.00
# grid num = 28
# Contour #741 — area: 0.00
# grid num = 28
# Contour #742 — area: 0.00
# grid num = 28
# Contour #743 — area: 2.00
# grid num = 28
# Contour #744 — area: 4.00
# grid num = 28
# Contour #745 — area: 0.00
# grid num = 28
# Contour #746 — area: 21.50
# grid num = 28
# Contour #747 — area: 10.00
# grid num = 28
# Contour #748 — area: 29.00
# grid num = 28
# Contour #749 — area: 23.50
# grid num = 28
# Contour #750 — area: 26.50
# grid num = 28
# Contour #751 — area: 28.50
# grid num = 28
# Contour #752 — area: 65.00
# grid num = 28
# Contour #753 — area: 56.00
# grid num = 28
# Contour #754 — area: 78.00
# grid num = 28
# Contour #755 — area: 123.00
# grid num = 28
# Contour #756 — area: 107.50
# grid num = 28
# Contour #757 — area: 65.00
# grid num = 28
# Contour #758 — area: 74.00
# grid num = 28
# Contour #759 — area: 47.00
# grid num = 28
# Contour #760 — area: 64.50
# grid num = 28
# Contour #761 — area: 18.50
# grid num = 28
# Contour #762 — area: 9.00
# grid num = 28
# Contour #763 — area: 3.50
# grid num = 28
# Contour #764 — area: 0.50
# grid num = 28
# Contour #765 — area: 7.50
# grid num = 28
# Contour #766 — area: 0.00
# grid num = 28
# Contour #767 — area: 9.00
# grid num = 28
# Contour #768 — area: 44.50
# grid num = 28
# Contour #769 — area: 38.50
# grid num = 28
# Contour #770 — area: 39.50
# grid num = 28
# Contour #771 — area: 15.50
# grid num = 28
# Contour #772 — area: 51.00
# grid num = 28
# Contour #773 — area: 29.00
# grid num = 28
# Contour #774 — area: 84.00
# grid num = 28
# Contour #775 — area: 81.00
# grid num = 28
# Contour #776 — area: 78.00
# grid num = 28
# Contour #777 — area: 163.50
# grid num = 28
# Contour #778 — area: 91.00
# grid num = 28
# Contour #779 — area: 101.50
# grid num = 28
# Contour #780 — area: 121.00
# grid num = 28
# Contour #781 — area: 77.50
# grid num = 28
# Contour #782 — area: 81.50
# grid num = 28
# Contour #783 — area: 94.50
# grid num = 28
# Contour #784 — area: 51.00
# grid num = 28
# Contour #785 — area: 24.00
# grid num = 28
# Contour #786 — area: 48.50
# grid num = 28
# Contour #787 — area: 8.00
# grid num = 28
# Contour #788 — area: 26.00
# grid num = 28
# Contour #789 — area: 31.50
# grid num = 28
# Contour #790 — area: 32.00
# grid num = 28
# Contour #791 — area: 26.00
# grid num = 28
# Contour #792 — area: 15.00
# grid num = 28
# Contour #793 — area: 95.00
# grid num = 28
# Contour #794 — area: 68.50
# grid num = 28
# Contour #795 — area: 41.00
# grid num = 28
# Contour #796 — area: 133.50
# grid num = 28
# Contour #797 — area: 96.50
# grid num = 28
# Contour #798 — area: 79.00
# grid num = 28
# Contour #799 — area: 86.50
# grid num = 28
# Contour #800 — area: 143.50
# grid num = 28
# Contour #801 — area: 105.50
# grid num = 28
# Contour #802 — area: 108.50
# grid num = 28
# Contour #803 — area: 122.00
# grid num = 28
# Contour #804 — area: 81.50
# grid num = 28
# Contour #805 — area: 70.50
# grid num = 28
# Contour #806 — area: 46.50
# grid num = 28
# Contour #807 — area: 34.50
# grid num = 28
# Contour #808 — area: 9.50
# grid num = 28
# Contour #809 — area: 3.50
# grid num = 28
# Contour #810 — area: 0.00
# grid num = 28
# Contour #811 — area: 0.00
# grid num = 28
# Contour #812 — area: 0.00
# grid num = 28
# Contour #813 — area: 0.00
# grid num = 28
# Contour #814 — area: 16.50
# grid num = 28
# Contour #815 — area: 41.00
# grid num = 28
# Contour #816 — area: 19.00
# grid num = 28
# Contour #817 — area: 5.50
# grid num = 28
# Contour #818 — area: 54.00
# grid num = 28
# Contour #819 — area: 51.00
# grid num = 28
# Contour #820 — area: 70.00
# grid num = 28
# Contour #821 — area: 51.00
# grid num = 28
# Contour #822 — area: 101.00
# grid num = 28
# Contour #823 — area: 85.00
# grid num = 28
# Contour #824 — area: 51.00
# grid num = 28
# Contour #825 — area: 93.00
# grid num = 28
# Contour #826 — area: 73.00
# grid num = 28
# Contour #827 — area: 48.00
# grid num = 28
# Contour #828 — area: 21.00
# grid num = 28
# Contour #829 — area: 24.00
# grid num = 28
# Contour #830 — area: 30.00
# grid num = 28
# Contour #831 — area: 40.50
# grid num = 28
# Contour #832 — area: 5.50
# grid num = 28
# Contour #833 — area: 16.50
# grid num = 28
# Contour #834 — area: 40.50
# grid num = 28
# Contour #835 — area: 68.00
# grid num = 28
# Contour #836 — area: 70.50
# grid num = 28
# Contour #837 — area: 75.50
# grid num = 28
# Contour #838 — area: 93.50
# grid num = 28
# Contour #839 — area: 95.00
# grid num = 28
# Contour #840 — area: 84.50
# grid num = 28
# Contour #841 — area: 78.50
# grid num = 28
# Contour #842 — area: 113.50
# grid num = 28
# Contour #843 — area: 176.50
# grid num = 28
# Contour #844 — area: 180.00
# grid num = 28
# Contour #845 — area: 154.00
# grid num = 28
# Contour #846 — area: 104.50
# grid num = 28
# Contour #847 — area: 142.50
# grid num = 28
# Contour #848 — area: 105.00
# grid num = 28
# Contour #849 — area: 93.00
# grid num = 28
# Contour #850 — area: 101.00
# grid num = 28
# Contour #851 — area: 51.00
# grid num = 28
# Contour #852 — area: 41.50
# grid num = 28
# Contour #853 — area: 38.00
# grid num = 28
# Contour #854 — area: 6.00
# grid num = 28
# Contour #855 — area: 7.50
# grid num = 28
# Contour #856 — area: 52.00
# grid num = 28
# Contour #857 — area: 49.00
# grid num = 28
# Contour #858 — area: 25.00
# grid num = 28
# Contour #859 — area: 52.00
# grid num = 28
# Contour #860 — area: 47.50
# grid num = 28
# Contour #861 — area: 72.00
# grid num = 28
# Contour #862 — area: 77.50
# grid num = 28
# Contour #863 — area: 107.00
# grid num = 28
# Contour #864 — area: 143.00
# grid num = 28
# Contour #865 — area: 86.00
# grid num = 28
# Contour #866 — area: 146.50
# grid num = 28
# Contour #867 — area: 159.00
# grid num = 28
# Contour #868 — area: 130.00
# grid num = 28
# Contour #869 — area: 106.00
# grid num = 28
# Contour #870 — area: 122.50
# grid num = 28
# Contour #871 — area: 152.50
# grid num = 28
# Contour #872 — area: 103.00
# grid num = 28
# Contour #873 — area: 65.50
# grid num = 28
# Contour #874 — area: 54.50
# grid num = 28
# Contour #875 — area: 42.00
# grid num = 28
# Contour #876 — area: 29.50
# grid num = 28
# Contour #877 — area: 28.50
# grid num = 28
# Contour #878 — area: 15.50
# grid num = 28
# Contour #879 — area: 45.00
# grid num = 28
# Contour #880 — area: 52.50
# grid num = 28
# Contour #881 — area: 31.00
# grid num = 28
# Contour #882 — area: 53.00
# grid num = 28
# Contour #883 — area: 56.00
# grid num = 28
# Contour #884 — area: 102.50
# grid num = 28
# Contour #885 — area: 95.50
# grid num = 28
# Contour #886 — area: 103.50
# grid num = 28
# Contour #887 — area: 917.50
# grid num = 29
# Contour #888 — area: 185.50
# grid num = 29
# Contour #889 — area: 152.50
# grid num = 29
# Contour #890 — area: 153.50
# grid num = 29
# Contour #891 — area: 99.00
# grid num = 29
# Contour #892 — area: 64.00
# grid num = 29
# Contour #893 — area: 49.50
# grid num = 29
# Contour #894 — area: 98.50
# grid num = 29
# Contour #895 — area: 56.00
# grid num = 29
# Contour #896 — area: 76.00
# grid num = 29
# Contour #897 — area: 47.00
# grid num = 29
# Contour #898 — area: 53.00
# grid num = 29
# Contour #899 — area: 13.00
# grid num = 29
# Contour #900 — area: 64.50
# grid num = 29
# Contour #901 — area: 13.00
# grid num = 29
# Contour #902 — area: 38.00
# grid num = 29
# Contour #903 — area: 39.50
# grid num = 29
# Contour #904 — area: 59.00
# grid num = 29
# Contour #905 — area: 69.00
# grid num = 29
# Contour #906 — area: 51.00
# grid num = 29
# Contour #907 — area: 50.00
# grid num = 29
# Contour #908 — area: 140.00
# grid num = 29
# Contour #909 — area: 82.50
# grid num = 29
# Contour #910 — area: 105.50
# grid num = 29
# Contour #911 — area: 931.50
# grid num = 30
# Contour #912 — area: 159.50
# grid num = 30
# Contour #913 — area: 223.50
# grid num = 30
# Contour #914 — area: 221.50
# grid num = 30
# Contour #915 — area: 177.50
# grid num = 30
# Contour #916 — area: 131.50
# grid num = 30
# Contour #917 — area: 126.00
# grid num = 30
# Contour #918 — area: 87.00
# grid num = 30
# Contour #919 — area: 75.50
# grid num = 30
# Contour #920 — area: 48.00
# grid num = 30
# Contour #921 — area: 16.50
# grid num = 30
# Contour #922 — area: 23.00
# grid num = 30
# Contour #923 — area: 24.00
# grid num = 30
# Contour #924 — area: 87.00
# grid num = 30
# Contour #925 — area: 78.00
# grid num = 30
# Contour #926 — area: 52.50
# grid num = 30
# Contour #927 — area: 54.50
# grid num = 30
# Contour #928 — area: 531.00
# grid num = 30
# Contour #929 — area: 579.50
# grid num = 30
# Contour #930 — area: 657.00
# grid num = 30
# Contour #931 — area: 683.00
# grid num = 30
# Contour #932 — area: 121.00
# grid num = 30
# Contour #933 — area: 892.50
# grid num = 31
# Contour #934 — area: 947.50
# grid num = 31
# Contour #935 — area: 233.00
# grid num = 31
# Contour #936 — area: 186.50
# grid num = 31
# Contour #937 — area: 121.00
# grid num = 31
# Contour #938 — area: 125.50
# grid num = 31
# Contour #939 — area: 207.00
# grid num = 31
# Contour #940 — area: 232.50
# grid num = 31
# Contour #941 — area: 109.50
# grid num = 31
# Contour #942 — area: 78.00
# grid num = 31
# Contour #943 — area: 28.50
# grid num = 31
# Contour #944 — area: 92.50
# grid num = 31
# Contour #945 — area: 101.00
# grid num = 31
# Contour #946 — area: 147.00
# grid num = 31
# Contour #947 — area: 128.50
# grid num = 31
# Contour #948 — area: 128.50
# grid num = 31
# Contour #949 — area: 137.00
# grid num = 31
# Contour #950 — area: 203.00
# grid num = 31
# Contour #951 — area: 165.50
# grid num = 31
# Contour #952 — area: 246.00
# grid num = 31
# Contour #953 — area: 720.50
# grid num = 31
# Contour #954 — area: 926.00
# grid num = 32
# Contour #955 — area: 1018.00
# grid num = 32
# Contour #956 — area: 1108.50
# grid num = 32
# Contour #957 — area: 169.50
# grid num = 32
# Contour #958 — area: 313.00
# grid num = 32
# Contour #959 — area: 231.00
# grid num = 32
# Contour #960 — area: 207.50
# grid num = 32
# Contour #961 — area: 135.50
# grid num = 32
# Contour #962 — area: 155.00
# grid num = 32
# Contour #963 — area: 195.00
# grid num = 32
# Contour #964 — area: 92.50
# grid num = 32
# Contour #965 — area: 60.00
# grid num = 32
# Contour #966 — area: 30.00
# grid num = 32
# Contour #967 — area: 49.00
# grid num = 32
# Contour #968 — area: 47.50
# grid num = 32
# Contour #969 — area: 81.50
# grid num = 32
# Contour #970 — area: 120.50
# grid num = 32
# Contour #971 — area: 76.50
# grid num = 32
# Contour #972 — area: 131.50
# grid num = 32
# Contour #973 — area: 52.50
# grid num = 32
# Contour #974 — area: 151.50
# grid num = 32
# Contour #975 — area: 631.50
# grid num = 32
# Contour #976 — area: 757.00
# grid num = 32
# Contour #977 — area: 853.50
# grid num = 33
# Contour #978 — area: 323.50
# grid num = 33
# Contour #979 — area: 216.00
# grid num = 33
# Contour #980 — area: 154.50
# grid num = 33
# Contour #981 — area: 197.00
# grid num = 33
# Contour #982 — area: 218.00
# grid num = 33
# Contour #983 — area: 208.50
# grid num = 33
# Contour #984 — area: 282.50
# grid num = 33
# Contour #985 — area: 79.00
# grid num = 33
# Contour #986 — area: 84.50
# grid num = 33
# Contour #987 — area: 48.50
# grid num = 33
# Contour #988 — area: 29.00
# grid num = 33
# Contour #989 — area: 35.00
# grid num = 33
# Contour #990 — area: 10.00
# grid num = 33
# Contour #991 — area: 26.50
# grid num = 33
# Contour #992 — area: 69.00
# grid num = 33
# Contour #993 — area: 76.50
# grid num = 33
# Contour #994 — area: 75.50
# grid num = 33
# Contour #995 — area: 548.00
# grid num = 33
# Contour #996 — area: 605.50
# grid num = 33
# Contour #997 — area: 654.00
# grid num = 33
# Contour #998 — area: 729.00
# grid num = 33
# Contour #999 — area: 800.50
# grid num = 34
# Contour #1000 — area: 233.00
# grid num = 34
# Contour #1001 — area: 977.50
# grid num = 35
# Contour #1002 — area: 175.00
# grid num = 35
# Contour #1003 — area: 250.00
# grid num = 35
# Contour #1004 — area: 208.50
# grid num = 35
# Contour #1005 — area: 187.00
# grid num = 35
# Contour #1006 — area: 194.50
# grid num = 35
# Contour #1007 — area: 135.50
# grid num = 35
# Contour #1008 — area: 106.00
# grid num = 35
# Contour #1009 — area: 79.50
# grid num = 35
# Contour #1010 — area: 87.00
# grid num = 35
# Contour #1011 — area: 35.50
# grid num = 35
# Contour #1012 — area: 28.50
# grid num = 35
# Contour #1013 — area: 36.50
# grid num = 35
# Contour #1014 — area: 43.00
# grid num = 35
# Contour #1015 — area: 56.50
# grid num = 35
# Contour #1016 — area: 105.00
# grid num = 35
# Contour #1017 — area: 104.00
# grid num = 35
# Contour #1018 — area: 137.00
# grid num = 35
# Contour #1019 — area: 96.50
# grid num = 35
# Contour #1020 — area: 629.00
# grid num = 35
# Contour #1021 — area: 721.50
# grid num = 35
# Contour #1022 — area: 788.50
# grid num = 36
# Contour #1023 — area: 877.00
# grid num = 36
# Contour #1024 — area: 131.00
# grid num = 36
# Contour #1025 — area: 245.00
# grid num = 36
# Contour #1026 — area: 178.00
# grid num = 36
# Contour #1027 — area: 266.50
# grid num = 36
# Contour #1028 — area: 175.50
# grid num = 36
# Contour #1029 — area: 88.50
# grid num = 36
# Contour #1030 — area: 159.00
# grid num = 36
# Contour #1031 — area: 111.00
# grid num = 36
# Contour #1032 — area: 87.50
# grid num = 36
# Contour #1033 — area: 47.50
# grid num = 36
# Contour #1034 — area: 18.00
# grid num = 36
# Contour #1035 — area: 7.00
# grid num = 36
# Contour #1036 — area: 94.00
# grid num = 36
# Contour #1037 — area: 89.50
# grid num = 36
# Contour #1038 — area: 109.50
# grid num = 36
# Contour #1039 — area: 503.50
# grid num = 36
# Contour #1040 — area: 559.00
# grid num = 36
# Contour #1041 — area: 615.00
# grid num = 36
# Contour #1042 — area: 685.50
# grid num = 36
# Contour #1043 — area: 779.50
# grid num = 36
# Contour #1044 — area: 755.00
# grid num = 36
# Contour #1045 — area: 155.00
# grid num = 36
# Contour #1046 — area: 168.50
# grid num = 36
# Contour #1047 — area: 187.50
# grid num = 36
# Contour #1048 — area: 194.50
# grid num = 36
# Contour #1049 — area: 140.00
# grid num = 36
# Contour #1050 — area: 128.00
# grid num = 36
# Contour #1051 — area: 93.50
# grid num = 36
# Contour #1052 — area: 143.50
# grid num = 36
# Contour #1053 — area: 91.50
# grid num = 36
# Contour #1054 — area: 136.50
# grid num = 36
# Contour #1055 — area: 67.00
# grid num = 36
# Contour #1056 — area: 35.00
# grid num = 36
# Contour #1057 — area: 41.00
# grid num = 36
# Contour #1058 — area: 59.50
# grid num = 36
# Contour #1059 — area: 41.50
# grid num = 36
# Contour #1060 — area: 94.50
# grid num = 36
# Contour #1061 — area: 120.00
# grid num = 36
# Contour #1062 — area: 55.00
# grid num = 36
# Contour #1063 — area: 98.00
# grid num = 36
# Contour #1064 — area: 622.00
# grid num = 36
# Contour #1065 — area: 640.50
# grid num = 36
# Contour #1066 — area: 185.00
# grid num = 36
# Contour #1067 — area: 826.00
# grid num = 37
# Contour #1068 — area: 911.00
# grid num = 37
# Contour #1069 — area: 926.00
# grid num = 37
# Contour #1070 — area: 260.00
# grid num = 37
# Contour #1071 — area: 223.50
# grid num = 37
# Contour #1072 — area: 238.00
# grid num = 37
# Contour #1073 — area: 222.00
# grid num = 37
# Contour #1074 — area: 178.50
# grid num = 37
# Contour #1075 — area: 222.00
# grid num = 37
# Contour #1076 — area: 140.00
# grid num = 37
# Contour #1077 — area: 86.00
# grid num = 37
# Contour #1078 — area: 39.00
# grid num = 37
# Contour #1079 — area: 37.50
# grid num = 37
# Contour #1080 — area: 46.50
# grid num = 37
# Contour #1081 — area: 68.50
# grid num = 37
# Contour #1082 — area: 123.50
# grid num = 37
# Contour #1083 — area: 129.50
# grid num = 37
# Contour #1084 — area: 168.00
# grid num = 37
# Contour #1085 — area: 152.00
# grid num = 37
# Contour #1086 — area: 652.00
# grid num = 37
# Contour #1087 — area: 676.50
# grid num = 37
# Contour #1088 — area: 800.00
# grid num = 38
# Contour #1089 — area: 802.50
# grid num = 38
# Contour #1090 — area: 907.00
# grid num = 38
# Contour #1091 — area: 1022.00
# grid num = 38
# Contour #1092 — area: 254.00
# grid num = 38
# Contour #1093 — area: 227.50
# grid num = 38
# Contour #1094 — area: 244.00
# grid num = 38
# Contour #1095 — area: 270.50
# grid num = 38
# Contour #1096 — area: 193.00
# grid num = 38
# Contour #1097 — area: 202.00
# grid num = 38
# Contour #1098 — area: 155.00
# grid num = 38
# Contour #1099 — area: 73.50
# grid num = 38
# Contour #1100 — area: 107.50
# grid num = 38
# Contour #1101 — area: 34.50
# grid num = 38
# Contour #1102 — area: 24.00
# grid num = 38
# Contour #1103 — area: 18.00
# grid num = 38
# Contour #1104 — area: 40.00
# grid num = 38
# Contour #1105 — area: 41.00
# grid num = 38
# Contour #1106 — area: 95.00
# grid num = 38
# Contour #1107 — area: 51.00
# grid num = 38
# Contour #1108 — area: 116.50
# grid num = 38
# Contour #1109 — area: 199.50
# grid num = 38
# Contour #1110 — area: 626.50
# grid num = 38
# Contour #1111 — area: 709.50
# grid num = 38
# Contour #1112 — area: 803.50
# grid num = 39
# Contour #1113 — area: 903.50
# grid num = 39
# Contour #1114 — area: 965.00
# grid num = 39
# Contour #1115 — area: 1009.50
# grid num = 39
# Contour #1116 — area: 221.50
# grid num = 39
# Contour #1117 — area: 290.00
# grid num = 39
# Contour #1118 — area: 345.00
# grid num = 39
# Contour #1119 — area: 251.00
# grid num = 39
# Contour #1120 — area: 215.50
# grid num = 39
# Contour #1121 — area: 188.00
# grid num = 39
# Contour #1122 — area: 162.00
# grid num = 39
# Contour #1123 — area: 142.50
# grid num = 39
# Contour #1124 — area: 53.00
# grid num = 39
# Contour #1125 — area: 57.00
# grid num = 39
# Contour #1126 — area: 68.50
# grid num = 39
# Contour #1127 — area: 123.50
# grid num = 39
# Contour #1128 — area: 116.50
# grid num = 39
# Contour #1129 — area: 426.00
# grid num = 39
# Contour #1130 — area: 495.50
# grid num = 39
# Contour #1131 — area: 537.50
# grid num = 39
# Contour #1132 — area: 670.00
# grid num = 39
# Contour #1133 — area: 769.50
# grid num = 39
# Contour #1134 — area: 763.50
# grid num = 39
# Contour #1135 — area: 856.50
# grid num = 40
# Contour #1136 — area: 880.00
# grid num = 40
# Contour #1137 — area: 1062.50
# grid num = 40
# Contour #1138 — area: 296.00
# grid num = 40
# Contour #1139 — area: 319.00
# grid num = 40
# Contour #1140 — area: 309.00
# grid num = 40
# Contour #1141 — area: 321.50
# grid num = 40
# Contour #1142 — area: 219.00
# grid num = 40
# Contour #1143 — area: 274.00
# grid num = 40
# Contour #1144 — area: 142.00
# grid num = 40
# Contour #1145 — area: 193.00
# grid num = 40
# Contour #1146 — area: 90.00
# grid num = 40
# Contour #1147 — area: 111.00
# grid num = 40
# Contour #1148 — area: 58.00
# grid num = 40
# Contour #1149 — area: 59.50
# grid num = 40
# Contour #1150 — area: 100.00
# grid num = 40
# Contour #1151 — area: 164.50
# grid num = 40
# Contour #1152 — area: 120.50
# grid num = 40
# Contour #1153 — area: 506.00
# grid num = 40
# Contour #1154 — area: 634.00
# grid num = 40
# Contour #1155 — area: 681.00
# grid num = 40
# Contour #1156 — area: 704.50
# grid num = 40
# Contour #1157 — area: 787.00
# grid num = 41
# Contour #1158 — area: 880.50
# ...
# grid num = 96
# Contour #2532 — area: 74.50
# grid num = 96
# Contour #2533 — area: 52.00
# grid num = 96
# Contour #2534 — area: 68.00
# grid num = 96
# Contour #2535 — area: 74.00
# grid num = 96
# Contour #2536 — area: 58.50
# grid num = 96
# Contour #2537 — area: 59.00
# grid num = 96
# Contour #2538 — area: 62.00
# grid num = 96
# Contour #2539 — area: 69.00
# grid num = 96
# Contour #2540 — area: 30.00
# grid num = 96
# Contour #2541 — area: 57.50
# grid num = 96
# Contour #2542 — area: 41.00
# grid num = 96
# Contour #2543 — area: 42.50
# grid num = 96
# Contour #2544 — area: 25.00
# grid num = 96
# Contour #2545 — area: 10.00
# grid num = 96
# Contour #2546 — area: 7.50
# grid num = 96
# Contour #2547 — area: 8.50
# grid num = 96
# Contour #2548 — area: 6.50
# grid num = 96
# Contour #2549 — area: 0.00
# grid num = 96
# Contour #2550 — area: 0.00
# grid num = 96
# Contour #2551 — area: 24.50
# grid num = 96
# Contour #2552 — area: 59.00
# grid num = 96
# Contour #2553 — area: 0.00
# grid num = 96
# Contour #2554 — area: 31.50
# grid num = 96
# Contour #2555 — area: 0.00
# grid num = 96
# Contour #2556 — area: 41.00
# grid num = 96
# Contour #2557 — area: 60.00
# grid num = 96
# Contour #2558 — area: 49.50
# grid num = 96
# Contour #2559 — area: 26.50
# grid num = 96
# Contour #2560 — area: 50.00
# grid num = 96
# Contour #2561 — area: 95.50
# grid num = 96
# Contour #2562 — area: 56.50
# grid num = 96
# Contour #2563 — area: 67.00
# grid num = 96
# Contour #2564 — area: 76.50
# grid num = 96
# Contour #2565 — area: 33.00
# grid num = 96
# Contour #2566 — area: 28.50
# grid num = 96
# Contour #2567 — area: 20.50
# grid num = 96
# Contour #2568 — area: 0.00
# grid num = 96
# Contour #2569 — area: 9.50
# grid num = 96
# Contour #2570 — area: 8.50
# grid num = 96
# Contour #2571 — area: 9.00
# grid num = 96
# Contour #2572 — area: 11.50
# grid num = 96
# Contour #2573 — area: 14.00
# grid num = 96
# Contour #2574 — area: 35.50
# grid num = 96
# Contour #2575 — area: 17.50
# grid num = 96
# Contour #2576 — area: 37.00
# grid num = 96
# Contour #2577 — area: 45.00
# grid num = 96
# Contour #2578 — area: 46.50
# grid num = 96
# Contour #2579 — area: 65.00
# grid num = 96
# Contour #2580 — area: 85.00
# grid num = 96
# Contour #2581 — area: 68.50
# grid num = 96
# Contour #2582 — area: 71.50
# grid num = 96
# Contour #2583 — area: 61.50
# grid num = 96
# Contour #2584 — area: 50.50
# grid num = 96
# Contour #2585 — area: 67.00
# grid num = 96
# Contour #2586 — area: 35.00
# grid num = 96
# Contour #2587 — area: 60.00
# grid num = 96
# Contour #2588 — area: 22.00
# grid num = 96
# Contour #2589 — area: 21.00
# grid num = 96
# Contour #2590 — area: 24.50
# grid num = 96
# Contour #2591 — area: 8.00
# grid num = 96
# Contour #2592 — area: 6.50
# grid num = 96
# Contour #2593 — area: 0.00
# grid num = 96
# Contour #2594 — area: 21.00
# grid num = 96
# Contour #2595 — area: 21.50
# grid num = 96
# Contour #2596 — area: 39.00
# grid num = 96
# Contour #2597 — area: 7.00
# grid num = 96
# Contour #2598 — area: 7.00
# grid num = 96
# Contour #2599 — area: 39.00
# grid num = 96
# Contour #2600 — area: 85.00
# grid num = 96
# Contour #2601 — area: 58.50
# grid num = 96
# Contour #2602 — area: 60.50
# grid num = 96
# Contour #2603 — area: 69.50
# grid num = 96
# Contour #2604 — area: 170.00
# grid num = 96
# Contour #2605 — area: 66.00
# grid num = 96
# Contour #2606 — area: 85.50
# grid num = 96
# Contour #2607 — area: 134.00
# grid num = 96
# Contour #2608 — area: 38.50
# grid num = 96
# Contour #2609 — area: 50.50
# grid num = 96
# Contour #2610 — area: 40.00
# grid num = 96
# Contour #2611 — area: 29.00
# grid num = 96
# Contour #2612 — area: 9.00
# grid num = 96
# Contour #2613 — area: 3.50
# grid num = 96
# Contour #2614 — area: 19.50
# grid num = 96
# Contour #2615 — area: 0.00
# grid num = 96
# Contour #2616 — area: 0.00
# grid num = 96
# Contour #2617 — area: 6.00
# grid num = 96
# Contour #2618 — area: 63.50
# grid num = 96
# Contour #2619 — area: 38.00
# grid num = 96
# Contour #2620 — area: 32.50
# grid num = 96
# Contour #2621 — area: 34.50
# grid num = 96
# Contour #2622 — area: 35.00
# grid num = 96
# Contour #2623 — area: 80.50
# grid num = 96
# Contour #2624 — area: 41.50
# grid num = 96
# Contour #2625 — area: 53.00
# grid num = 96
# Contour #2626 — area: 37.50
# grid num = 96
# Contour #2627 — area: 102.50
# grid num = 96
# Contour #2628 — area: 108.50
# grid num = 96
# Contour #2629 — area: 58.00
# grid num = 96
# Contour #2630 — area: 72.00
# grid num = 96
# Contour #2631 — area: 65.50
# grid num = 96
# Contour #2632 — area: 37.00
# grid num = 96
# Contour #2633 — area: 62.50
# grid num = 96
# Contour #2634 — area: 41.00
# grid num = 96
# Contour #2635 — area: 16.50
# grid num = 96
# Contour #2636 — area: 22.00
# grid num = 96
# Contour #2637 — area: 6.50
# grid num = 96
# Contour #2638 — area: 12.50
# grid num = 96
# Contour #2639 — area: 45.50
# grid num = 96
# Contour #2640 — area: 32.50
# grid num = 96
# Contour #2641 — area: 51.50
# grid num = 96
# Contour #2642 — area: 70.00
# grid num = 96
# Contour #2643 — area: 100.50
# grid num = 96
# Contour #2644 — area: 55.00
# grid num = 96
# Contour #2645 — area: 40.50
# grid num = 96
# Contour #2646 — area: 171.50
# grid num = 96
# Contour #2647 — area: 132.00
# grid num = 96
# Contour #2648 — area: 123.50
# grid num = 96
# Contour #2649 — area: 110.50
# grid num = 96
# Contour #2650 — area: 146.50
# grid num = 96
# Contour #2651 — area: 76.00
# grid num = 96
# Contour #2652 — area: 63.50
# grid num = 96
# Contour #2653 — area: 58.50
# grid num = 96
# Contour #2654 — area: 45.50
# grid num = 96
# Contour #2655 — area: 51.50
# grid num = 96
# Contour #2656 — area: 24.50
# grid num = 96
# Contour #2657 — area: 39.00
# grid num = 96
# Contour #2658 — area: 14.00
# grid num = 96
# Contour #2659 — area: 23.00
# grid num = 96
# Contour #2660 — area: 15.50
# grid num = 96
# Contour #2661 — area: 8.50
# grid num = 96
# Contour #2662 — area: 38.50
# grid num = 96
# Contour #2663 — area: 31.50
# grid num = 96
# Contour #2664 — area: 46.50
# grid num = 96
# Contour #2665 — area: 76.50
# grid num = 96
# Contour #2666 — area: 99.50
# grid num = 96
# Contour #2667 — area: 736.50
# grid num = 96
# Contour #2668 — area: 93.00
# grid num = 96
# Contour #2669 — area: 137.00
# grid num = 96
# Contour #2670 — area: 181.50
# grid num = 96
# Contour #2671 — area: 127.50
# grid num = 96
# Contour #2672 — area: 179.50
# grid num = 96
# Contour #2673 — area: 135.00
# grid num = 96
# Contour #2674 — area: 94.50
# grid num = 96
# Contour #2675 — area: 71.50
# grid num = 96
# Contour #2676 — area: 55.00
# grid num = 96
# Contour #2677 — area: 57.00
# grid num = 96
# Contour #2678 — area: 38.50
# grid num = 96
# Contour #2679 — area: 34.50
# grid num = 96
# Contour #2680 — area: 21.00
# grid num = 96
# Contour #2681 — area: 7.50
# grid num = 96
# Contour #2682 — area: 29.50
# grid num = 96
# Contour #2683 — area: 22.00
# grid num = 96
# Contour #2684 — area: 31.50
# grid num = 96
# Contour #2685 — area: 46.50
# grid num = 96
# Contour #2686 — area: 29.50
# grid num = 96
# Contour #2687 — area: 49.00
# grid num = 96
# Contour #2688 — area: 75.00
# grid num = 96
# Contour #2689 — area: 641.00
# grid num = 96
# Contour #2690 — area: 790.50
# grid num = 97
# Contour #2691 — area: 882.50
# grid num = 97
# Contour #2692 — area: 882.00
# grid num = 97
# Contour #2693 — area: 89.50
# grid num = 97
# Contour #2694 — area: 119.00
# grid num = 97
# Contour #2695 — area: 75.00
# grid num = 97
# Contour #2696 — area: 160.00
# grid num = 97
# Contour #2697 — area: 137.00
# grid num = 97
# Contour #2698 — area: 105.50
# grid num = 97
# Contour #2699 — area: 48.50
# grid num = 97
# Contour #2700 — area: 108.50
# grid num = 97
# Contour #2701 — area: 52.00
# grid num = 97
# Contour #2702 — area: 33.00
# grid num = 97
# Contour #2703 — area: 12.00
# grid num = 97
# Contour #2704 — area: 23.00
# grid num = 97
# Contour #2705 — area: 58.50
# grid num = 97
# Contour #2706 — area: 21.50
# grid num = 97
# Contour #2707 — area: 78.50
# grid num = 97
# Contour #2708 — area: 85.00
# grid num = 97
# Contour #2709 — area: 83.00
# grid num = 97
# Contour #2710 — area: 115.50
# grid num = 97
# Contour #2711 — area: 675.00
# grid num = 97
# Contour #2712 — area: 98.00
# grid num = 97
# Contour #2713 — area: 779.50
# grid num = 97
# Contour #2714 — area: 103.00
# grid num = 97
# Contour #2715 — area: 929.00
# grid num = 98
# Contour #2716 — area: 167.50
# grid num = 98
# Contour #2717 — area: 109.50
# grid num = 98
# Contour #2718 — area: 145.00
# grid num = 98
# Contour #2719 — area: 143.00
# grid num = 98
# Contour #2720 — area: 72.50
# grid num = 98
# Contour #2721 — area: 86.50
# grid num = 98
# Contour #2722 — area: 66.00
# grid num = 98
# Contour #2723 — area: 32.00
# grid num = 98
# Contour #2724 — area: 42.50
# grid num = 98
# Contour #2725 — area: 34.00
# grid num = 98
# Contour #2726 — area: 11.00
# grid num = 98
# Contour #2727 — area: 36.00
# grid num = 98
# Contour #2728 — area: 24.50
# grid num = 98
# Contour #2729 — area: 68.00
# grid num = 98
# Contour #2730 — area: 83.00
# grid num = 98
# Contour #2731 — area: 118.00
# grid num = 98
# Contour #2732 — area: 610.00
# grid num = 98
# Contour #2733 — area: 668.50
# grid num = 98
# Contour #2734 — area: 769.00
# grid num = 98
# Contour #2735 — area: 862.50
# grid num = 99
# Contour #2736 — area: 156.50
# grid num = 99
# Contour #2737 — area: 114.50
# grid num = 99
# Contour #2738 — area: 136.00
# grid num = 99
# Contour #2739 — area: 106.50
# grid num = 99
# Contour #2740 — area: 138.00
# grid num = 99
# Contour #2741 — area: 66.00
# grid num = 99
# Contour #2742 — area: 52.50
# grid num = 99
# Contour #2743 — area: 95.50
# grid num = 99
# Contour #2744 — area: 59.00
# grid num = 99
# Contour #2745 — area: 46.50
# grid num = 99
# Contour #2746 — area: 22.50
# grid num = 99
# Contour #2747 — area: 11.50
# grid num = 99
# Contour #2748 — area: 6.00
# grid num = 99
# Contour #2749 — area: 5.00
# grid num = 99
# Contour #2750 — area: 6.50
# grid num = 99
# Contour #2751 — area: 57.50
# grid num = 99
# Contour #2752 — area: 50.50
# grid num = 99
# Contour #2753 — area: 42.50
# grid num = 99
# Contour #2754 — area: 18.50
# grid num = 99
# Contour #2755 — area: 62.50
# grid num = 99
# Contour #2756 — area: 142.50
# grid num = 99
# Contour #2757 — area: 711.00
# grid num = 99
# Contour #2758 — area: 111.50
# grid num = 99
# Contour #2759 — area: 842.50
# grid num = 100
# Contour #2760 — area: 178.50
# grid num = 100
# Contour #2761 — area: 123.50
# grid num = 100
# Contour #2762 — area: 141.50
# grid num = 100
# Contour #2763 — area: 122.00
# grid num = 100
# Contour #2764 — area: 167.00
# grid num = 100
# Contour #2765 — area: 134.00
# grid num = 100
# Contour #2766 — area: 130.00
# grid num = 100
# Contour #2767 — area: 96.00
# grid num = 100
# Contour #2768 — area: 83.50
# grid num = 100
# Contour #2769 — area: 60.50
# grid num = 100
# Contour #2770 — area: 41.50
# grid num = 100
# Contour #2771 — area: 7.00
# grid num = 100
# Contour #2772 — area: 37.50
# grid num = 100
# Contour #2773 — area: 35.00
# grid num = 100
# Contour #2774 — area: 24.50
# grid num = 100
# Contour #2775 — area: 28.00
# grid num = 100
# Contour #2776 — area: 87.50
# grid num = 100
# Contour #2777 — area: 628.50
# grid num = 100
# Contour #2778 — area: 94.50
# grid num = 100
# Contour #2779 — area: 84.00
# grid num = 100
# Contour #2780 — area: 842.00
# grid num = 101
# Contour #2781 — area: 217.00
# grid num = 101
# Contour #2782 — area: 906.00
# grid num = 102
# Contour #2783 — area: 154.50
# grid num = 102
# Contour #2784 — area: 186.50
# grid num = 102
# Contour #2785 — area: 111.50
# grid num = 102
# Contour #2786 — area: 188.00
# grid num = 102
# Contour #2787 — area: 70.00
# grid num = 102
# Contour #2788 — area: 88.00
# grid num = 102
# Contour #2789 — area: 76.50
# grid num = 102
# Contour #2790 — area: 46.50
# grid num = 102
# Contour #2791 — area: 41.50
# grid num = 102
# Contour #2792 — area: 25.00
# grid num = 102
# Contour #2793 — area: 28.50
# grid num = 102
# Contour #2794 — area: 38.00
# grid num = 102
# Contour #2795 — area: 32.50
# grid num = 102
# Contour #2796 — area: 79.50
# grid num = 102
# Contour #2797 — area: 55.50
# grid num = 102
# Contour #2798 — area: 531.00
# grid num = 102
# Contour #2799 — area: 618.50
# grid num = 102
# Contour #2800 — area: 624.00
# grid num = 102
# Contour #2801 — area: 105.00
# grid num = 102
# Contour #2802 — area: 735.50
# grid num = 102
# Contour #2803 — area: 824.50
# grid num = 103
# Contour #2804 — area: 942.50
# grid num = 103
# Contour #2805 — area: 924.50
# grid num = 103
# Contour #2806 — area: 180.50
# grid num = 103
# Contour #2807 — area: 221.50
# grid num = 103
# Contour #2808 — area: 148.00
# grid num = 103
# Contour #2809 — area: 231.50
# grid num = 103
# Contour #2810 — area: 180.00
# grid num = 103
# Contour #2811 — area: 133.50
# grid num = 103
# Contour #2812 — area: 119.50
# grid num = 103
# Contour #2813 — area: 83.50
# grid num = 103
# Contour #2814 — area: 109.50
# grid num = 103
# Contour #2815 — area: 76.00
# grid num = 103
# Contour #2816 — area: 12.00
# grid num = 103
# Contour #2817 — area: 48.50
# grid num = 103
# Contour #2818 — area: 50.00
# grid num = 103
# Contour #2819 — area: 61.50
# grid num = 103
# Contour #2820 — area: 44.50
# grid num = 103
# Contour #2821 — area: 149.50
# grid num = 103
# Contour #2822 — area: 72.00
# grid num = 103
# Contour #2823 — area: 665.50
# grid num = 103
# Contour #2824 — area: 702.00
# grid num = 103
# Contour #2825 — area: 777.50
# grid num = 103
# Contour #2826 — area: 911.50
# grid num = 104
# Contour #2827 — area: 918.50
# grid num = 104
# Contour #2828 — area: 185.00
# grid num = 104
# Contour #2829 — area: 212.50
# grid num = 104
# Contour #2830 — area: 170.00
# grid num = 104
# Contour #2831 — area: 206.00
# grid num = 104
# Contour #2832 — area: 161.50
# grid num = 104
# Contour #2833 — area: 214.50
# grid num = 104
# Contour #2834 — area: 156.00
# grid num = 104
# Contour #2835 — area: 130.00
# grid num = 104
# Contour #2836 — area: 65.50
# grid num = 104
# Contour #2837 — area: 57.00
# grid num = 104
# Contour #2838 — area: 30.50
# grid num = 104
# Contour #2839 — area: 35.50
# grid num = 104
# Contour #2840 — area: 32.50
# grid num = 104
# Contour #2841 — area: 16.00
# grid num = 104
# Contour #2842 — area: 44.00
# grid num = 104
# Contour #2843 — area: 46.00
# grid num = 104
# Contour #2844 — area: 86.00
# grid num = 104
# Contour #2845 — area: 635.00
# grid num = 104
# Contour #2846 — area: 64.50
# grid num = 104
# Contour #2847 — area: 796.50
# grid num = 105
# Contour #2848 — area: 852.00
# grid num = 105
# Contour #2849 — area: 938.50
# grid num = 105
# Contour #2850 — area: 125.00
# grid num = 105
# Contour #2851 — area: 186.50
# grid num = 105
# Contour #2852 — area: 167.50
# grid num = 105
# Contour #2853 — area: 155.00
# grid num = 105
# Contour #2854 — area: 135.50
# grid num = 105
# Contour #2855 — area: 94.50
# grid num = 105
# Contour #2856 — area: 82.50
# grid num = 105
# Contour #2857 — area: 61.50
# grid num = 105
# Contour #2858 — area: 52.00
# grid num = 105
# Contour #2859 — area: 36.00
# grid num = 105
# Contour #2860 — area: 27.50
# grid num = 105
# Contour #2861 — area: 3.00
# grid num = 105
# Contour #2862 — area: 8.00
# grid num = 105
# Contour #2863 — area: 9.00
# grid num = 105
# Contour #2864 — area: 0.00
# grid num = 105
# Contour #2865 — area: 7.00
# grid num = 105
# Contour #2866 — area: 0.00
# grid num = 105
# Contour #2867 — area: 33.00
# grid num = 105
# Contour #2868 — area: 15.50
# grid num = 105
# Contour #2869 — area: 8.50
# grid num = 105
# Contour #2870 — area: 17.00
# grid num = 105
# Contour #2871 — area: 64.50
# grid num = 105
# Contour #2872 — area: 28.50
# grid num = 105
# Contour #2873 — area: 93.00
# grid num = 105
# Contour #2874 — area: 56.50
# grid num = 105
# Contour #2875 — area: 88.50
# grid num = 105
# Contour #2876 — area: 37.50
# grid num = 105
# Contour #2877 — area: 107.00
# grid num = 105
# Contour #2878 — area: 50.50
# grid num = 105
# Contour #2879 — area: 64.00
# grid num = 105
# Contour #2880 — area: 37.50
# grid num = 105
# Contour #2881 — area: 32.00
# grid num = 105
# Contour #2882 — area: 24.00
# grid num = 105
# Contour #2883 — area: 7.50
# grid num = 105
# Contour #2884 — area: 0.00
# grid num = 105
# Contour #2885 — area: 0.50
# grid num = 105
# Contour #2886 — area: 8.00
# grid num = 105
# Contour #2887 — area: 0.00
# grid num = 105
# Contour #2888 — area: 32.00
# grid num = 105
# Contour #2889 — area: 7.00
# grid num = 105
# Contour #2890 — area: 0.00
# grid num = 105
# Contour #2891 — area: 14.00
# grid num = 105
# Contour #2892 — area: 22.00
# grid num = 105
# Contour #2893 — area: 69.50
# grid num = 105
# Contour #2894 — area: 40.50
# grid num = 105
# Contour #2895 — area: 20.50
# grid num = 105
# Contour #2896 — area: 73.00
# grid num = 105
# Contour #2897 — area: 59.50
# grid num = 105
# Contour #2898 — area: 48.00
# grid num = 105
# Contour #2899 — area: 48.00
# grid num = 105
# Contour #2900 — area: 37.50
# grid num = 105
# Contour #2901 — area: 31.50
# grid num = 105
# Contour #2902 — area: 30.50
# grid num = 105
# Contour #2903 — area: 40.50
# grid num = 105
# Contour #2904 — area: 42.00
# grid num = 105
# Contour #2905 — area: 42.50
# grid num = 105
# Contour #2906 — area: 25.00
# grid num = 105
