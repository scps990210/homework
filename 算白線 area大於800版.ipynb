# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import cv2

area_prev = 0
area_now = 0
grid_num = 0
i = 1
flag = 1

for i in range(1,100):      #迴圈次數自己選擇
    img = cv2.imread('%d.jpg' %(i))#路徑自己選擇

# 讀取一張照片
#img = cv2.imread('15.jpg')
    x=375
    y=275
    w=35
    h=30
    img = img[y:y+h, x: x+w]


# 不直接指定縮放後大小，通過fx和fy指定縮放比例，0.5則長寬都爲原來一半
# 等效於img_200x300 = cv2.resize(img, (300, 200))，注意指定大小的格式是(寬度,高度)
# 插值方法默認是cv2.INTER_LINEAR，這裏指定爲最近鄰插值
    img = cv2.resize(img, (0, 0), fx=3.5, fy=3.5, 
                              interpolation=cv2.INTER_NEAREST)
    imgContour = img.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    canny = cv2.Canny(img, 150, 200)
    contours, hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)



    peak=0.0
    for cnt in contours:
        area = cv2.contourArea(cnt)
        if area > peak and area > 0:
            peak = area
    print ("Contour #%d — area: %.2f" % (i, peak))
    i=i+1
    """
    #算經過幾格
    flag = 0
    area_now = peak
    if flag == 1 and area_now < area_prev:
        grid_num = grid_num + 1
    if area_now > area_prev:
        flag = 1
    else:
        flag = 0
    area_prev = peak
    """
    if area > 800:
        if flag == 0:
            grid_num += 1
            print("flag = %d" %flag)
        flag = 1
    else :
        flag = 0
    print ("grid num = %d"%grid_num )
        
        
    
    for cnt in contours:
    # 每個找出的輪廓
    #cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
    # 藍線框起
        area = cv2.contourArea(cnt)
    #if area > peak:
    #    peak = area
    #print ("Contour #%d — area: %.2f" % (i, area))
    #i=i+1

        if area == peak:
            cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
            #print("Contour drawed area = %.2f" %area)
            print('%.2f' %cv2.arcLength(cnt, True))
            # True表示輪廓為closed
            peri2 = cv2.arcLength(cnt, False)
            peri = cv2.arcLength(cnt, True)
            #算出周長
            vertices = cv2.approxPolyDP(cnt, peri * 0.2, True)
            vertices2 = cv2.approxPolyDP(cnt, peri2 * 0.2, False)
            #得出多邊形角點
            corners = len(vertices)
            corner = len(vertices2)
            #角點個數
         
            #print(corners)
            #print('123')
            #print(corner)
            x, y, w, h = cv2.boundingRect(vertices)
            
            cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4)
            #a+=1.0
        #while cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4):
             #a+=1
        #if corners == 3:
             #cv2.putText(imgContour,'triangle', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                
                
        #else: 
            cv2.putText(imgContour, 'full', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    #cv2.imshow('img', img)
    #cv2.imshow('canny', canny)
    #cv2.imshow('img%d' %i, imgContour)
    #cv2.waitKey(0) 


# In[ ]:
# Out:
# Contour #1 — area: 83.00
# grid num = 0
# 392.33
# Contour #2 — area: 674.00
# grid num = 0
# 201.82
# Contour #3 — area: 705.00
# grid num = 0
# 212.31
# Contour #4 — area: 866.00
# flag = 0
# grid num = 1
# 246.45
# Contour #5 — area: 925.00
# grid num = 1
# 280.25
# Contour #6 — area: 1048.00
# grid num = 1
# 279.76
# Contour #7 — area: 1067.50
# grid num = 1
# 271.52
# Contour #8 — area: 212.50
# grid num = 1
# 547.63
# Contour #9 — area: 187.00
# grid num = 1
# 500.90
# Contour #10 — area: 150.00
# grid num = 1
# 427.45
# Contour #11 — area: 178.00
# grid num = 1
# 388.33
# Contour #12 — area: 203.50
# grid num = 1
# 354.29
# Contour #13 — area: 66.00
# grid num = 1
# 302.25
# Contour #14 — area: 71.00
# grid num = 1
# 255.28
# Contour #15 — area: 71.50
# grid num = 1
# 174.27
# Contour #16 — area: 32.50
# grid num = 1
# 189.78
# Contour #17 — area: 27.50
# grid num = 1
# 208.41
# Contour #18 — area: 33.50
# grid num = 1
# 127.64
# Contour #19 — area: 431.50
# grid num = 1
# ...
