# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import cv2

area_prev = 0
area_now = 0
grid_num = 0
i = 1
flag = 0

for i in range(5700,7633):
    #5700-6530共71個
    #5700-7633共166個
    img = cv2.imread('images/images%d.jpg' %(i))

# 讀取一張照片
#img = cv2.imread('15.jpg')
    x=1035
    y=410
    w=45
    h=40
    img = img[y:y+h, x: x+w]
    

# 不直接指定縮放後大小，通過fx和fy指定縮放比例，0.5則長寬都爲原來一半
# 等效於img_200x300 = cv2.resize(img, (300, 200))，注意指定大小的格式是(寬度,高度)
# 插值方法默認是cv2.INTER_LINEAR，這裏指定爲最近鄰插值
    img = cv2.resize(img, (0, 0), fx=3.5, fy=3.5, 
                              interpolation=cv2.INTER_NEAREST)
    imgContour = img.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    canny = cv2.Canny(img, 70, 210)
    contours, hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)



    peak=0.0
    for cnt in contours:
        area = cv2.contourArea(cnt)
        if area > peak and area > 0:
            peak = area
    print ("Contour #%d — area: %.2f" % (i, peak))
    i=i+1
    """
    #算經過幾格
    flag = 0
    area_now = peak
    if flag == 1 and area_now < area_prev:
        grid_num = grid_num + 1
    if area_now > area_prev:
        flag = 1
    else:
        flag = 0
    area_prev = peak
    """
    if peak > 1200:
        if flag == 0:
            grid_num += 1
        flag = 1
    else :
        flag = 0
    print ("grid num = %d"%grid_num )
        
        
    
    for cnt in contours:
    # 每個找出的輪廓
    #cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
    # 藍線框起
        area = cv2.contourArea(cnt)
    #if area > peak:
    #    peak = area
    #print ("Contour #%d — area: %.2f" % (i, area))
    #i=i+1

        if area == peak:
            cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
            #print("Contour drawed area = %.2f" %area)
            #print('%.2f' %cv2.arcLength(cnt, True))
            # True表示輪廓為closed
            peri2 = cv2.arcLength(cnt, False)
            peri = cv2.arcLength(cnt, True)
            #算出周長
            vertices = cv2.approxPolyDP(cnt, peri * 0.2, True)
            vertices2 = cv2.approxPolyDP(cnt, peri2 * 0.2, False)
            #得出多邊形角點
            corners = len(vertices)
            corner = len(vertices2)
            #角點個數
         
            #print(corners)
            #print('123')
            #print(corner)
            x, y, w, h = cv2.boundingRect(vertices)
            
            cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4)
        #while cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4):
             #a+=1
        #if corners == 3:
             #cv2.putText(imgContour,'triangle', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                
                
        #else: 
            cv2.putText(imgContour, 'full', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    #cv2.imshow('img', img)
    #cv2.imshow('canny', canny)
    cv2.imshow('img%d' %i, imgContour)
    cv2.waitKey(0) 


# In[ ]:
# Out:
# Contour #5700 — area: 2001.50
# grid num = 1
# Contour #5701 — area: 771.50
# grid num = 1
# Contour #5702 — area: 737.50
# grid num = 1
# Contour #5703 — area: 567.50
# grid num = 1
# Contour #5704 — area: 381.00
# grid num = 1
# Contour #5705 — area: 157.50
# grid num = 1
# Contour #5706 — area: 27.00
# grid num = 1
# Contour #5707 — area: 212.00
# grid num = 1
# Contour #5708 — area: 363.50
# grid num = 1
# Contour #5709 — area: 563.00
# grid num = 1
# Contour #5710 — area: 725.00
# grid num = 1
# Contour #5711 — area: 1745.00
# grid num = 2
# Contour #5712 — area: 1979.50
# grid num = 2
# Contour #5713 — area: 844.00
# grid num = 2
# Contour #5714 — area: 665.50
# grid num = 2
# Contour #5715 — area: 436.50
# grid num = 2
# Contour #5716 — area: 406.50
# grid num = 2
# Contour #5717 — area: 249.50
# grid num = 2
# Contour #5718 — area: 192.00
# grid num = 2
# Contour #5719 — area: 338.00
# grid num = 2
# Contour #5720 — area: 482.50
# grid num = 2
# Contour #5721 — area: 1310.50
# grid num = 3
# Contour #5722 — area: 1537.50
# grid num = 3
# Contour #5723 — area: 1749.50
# grid num = 3
# Contour #5724 — area: 1904.00
# grid num = 3
# Contour #5725 — area: 2163.00
# grid num = 3
# Contour #5726 — area: 846.00
# grid num = 3
# Contour #5727 — area: 744.00
# grid num = 3
# Contour #5728 — area: 664.50
# grid num = 3
# Contour #5729 — area: 474.50
# grid num = 3
# Contour #5730 — area: 247.00
# grid num = 3
# Contour #5731 — area: 364.00
# grid num = 3
# Contour #5732 — area: 455.50
# grid num = 3
# Contour #5733 — area: 548.00
# grid num = 3
# Contour #5734 — area: 1446.50
# grid num = 4
# Contour #5735 — area: 1564.00
# grid num = 4
# Contour #5736 — area: 1972.50
# grid num = 4
# Contour #5737 — area: 2296.50
# grid num = 4
# Contour #5738 — area: 2487.00
# grid num = 4
# Contour #5739 — area: 939.50
# grid num = 4
# Contour #5740 — area: 797.50
# grid num = 4
# Contour #5741 — area: 676.50
# grid num = 4
# Contour #5742 — area: 518.00
# grid num = 4
# Contour #5743 — area: 278.50
# grid num = 4
# Contour #5744 — area: 409.50
# grid num = 4
# Contour #5745 — area: 414.50
# grid num = 4
# Contour #5746 — area: 656.00
# grid num = 4
# Contour #5747 — area: 664.00
# grid num = 4
# Contour #5748 — area: 2101.50
# grid num = 5
# Contour #5749 — area: 2393.00
# grid num = 5
# Contour #5750 — area: 2808.00
# grid num = 5
# Contour #5751 — area: 1117.50
# grid num = 5
# Contour #5752 — area: 958.00
# grid num = 5
# Contour #5753 — area: 771.00
# grid num = 5
# Contour #5754 — area: 616.00
# grid num = 5
# Contour #5755 — area: 348.00
# grid num = 5
# Contour #5756 — area: 303.00
# grid num = 5
# Contour #5757 — area: 515.50
# grid num = 5
# Contour #5758 — area: 615.00
# grid num = 5
# Contour #5759 — area: 743.00
# grid num = 5
# Contour #5760 — area: 2065.00
# grid num = 6
# Contour #5761 — area: 2418.00
# grid num = 6
# Contour #5762 — area: 2778.50
# grid num = 6
# Contour #5763 — area: 1220.00
# grid num = 6
# Contour #5764 — area: 1092.00
# grid num = 6
# Contour #5765 — area: 1170.00
# grid num = 6
