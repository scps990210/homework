# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import cv2

area_prev = 0
area_now = 0

for i in range(1,20):      #迴圈次數自己選擇
    img = cv2.imread('%d.jpg' %(i))#路徑自己選擇

# 讀取一張照片
#img = cv2.imread('15.jpg')
    x=375
    y=275
    w=35
    h=30
    #img = img[y:y+h, x: x+w]


# 不直接指定縮放後大小，通過fx和fy指定縮放比例，0.5則長寬都爲原來一半
# 等效於img_200x300 = cv2.resize(img, (300, 200))，注意指定大小的格式是(寬度,高度)
# 插值方法默認是cv2.INTER_LINEAR，這裏指定爲最近鄰插值
    #img = cv2.resize(img, (0, 0), fx=3.5, fy=3.5, 
                              #interpolation=cv2.INTER_NEAREST)
    imgContour = img.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    canny = cv2.Canny(img, 150, 200)
    contours, hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)



    peak=0.0
    i=1.0
    for cnt in contours:
        area = cv2.contourArea(cnt)
        if area > peak:
            peak = area
        print ("Contour #%d — area: %.2f" % (i, area))
        i=i+1
    #算經過幾格
    grid_num = 0
    flag = 0
    area_now = peak
    if flag == 1 and area_now < area_prev:
        grid_num = grid_num + 1
    if area_now > area_prev:
        flag = 1
    else:
        flag = 0
    area_prev = peak
    
    for cnt in contours:
    # 每個找出的輪廓
    #cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
    # 藍線框起
        area = cv2.contourArea(cnt)
    #if area > peak:
    #    peak = area
    #print ("Contour #%d — area: %.2f" % (i, area))
    #i=i+1

        if area == peak:
            cv2.drawContours(imgContour, cnt, -1, (255, 0, 0), 4)
            print("Contour drawed area = %.2f" %area)
            # print(cv2.arcLength(cnt, True))
            # True表示輪廓為closed
            peri2 = cv2.arcLength(cnt, False)
            peri = cv2.arcLength(cnt, True)
            #算出周長
            vertices = cv2.approxPolyDP(cnt, peri * 0.2, True)
            vertices2 = cv2.approxPolyDP(cnt, peri2 * 0.2, False)
            #得出多邊形角點
            corners = len(vertices)
            corner = len(vertices2)
            #角點個數
         
            print(corners)
            print('123')
            print(corner)
            x, y, w, h = cv2.boundingRect(vertices)
            
            cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4)
            a+=1.0
        #while cv2.rectangle(imgContour, (x, y), (x+w, y+h), (0, 255, 0), 4):
             #a+=1
        #if corners == 3:
             #cv2.putText(imgContour,'triangle', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                
                
        #else: 
            cv2.putText(imgContour, 'full', (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    cv2.imshow('img', img)
    #cv2.imshow('canny', canny)
    cv2.imshow('img1', imgContour)
    cv2.waitKey(0) 


# In[ ]:
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 12>()
#      20 h=30
#      21 #img = img[y:y+h, x: x+w]
#      22
#      23
#    (...)
#      27 #img = cv2.resize(img, (0, 0), fx=3.5, fy=3.5,
#      28                           #interpolation=cv2.INTER_NEAREST)
# ---> 29 imgContour = img.copy()
#      30 img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      31 canny = cv2.Canny(img, 150, 200)
#
# AttributeError: 'NoneType' object has no attribute 'copy'
